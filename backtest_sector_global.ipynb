# %%
from pathlib import Path

from backtest_util import *
import backtest_XGB

EXPERIMENT    = "full_dataset"       # matches results/final_<NAME>_reg.ubj
SECTORS       =  ["financial_services"]        # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0                # 0 = long-only
REBALANCE     = "fixed"               # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_v2")

df = load_dataset(SECTORS)
START, END = infer_test_window(df)
print(f"Test window: {START}  →  {END}")

results = backtest_XGB.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
    cleanup_sectors = None,
)
# Out:
# GPU detected: NVIDIA GeForce GTX 1070, 8192 MiB
# Dataset: 25,931 rows | 602 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded ensemble [full_dataset]  (3 models | train IC=0.0775) ICIR=1.0254
# Dataset: 25,931 rows | 602 tickers
# Dataset: 146,809 rows | 3,773 tickers
# [cleanup] fit on global pre-backtest data (91560 rows)
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLF
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] matured start (2021-07-02) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-10-02
# 2023Q1 n=533→ 27 long=+2.44%  comb=+2.44% SPY≈+8.68% sector≈+5.32% alpha=-6.24% sector_alpha=-2.88% IC(Batch)=+0.016
#   [retrain] matured start (2021-09-30) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-12-31
# 2023Q2 n=534→ 27 long=-0.88%  comb=-0.88% SPY≈-3.26% sector≈-2.00% alpha=+2.38% sector_alpha=+1.12% IC(Batch)=+0.093
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] ensemble member 0: fit on 389 rows from range 2022-01-03 - 2022-03-17
#   [retrain] ensemble member 1: fit on 440 rows from range 2022-01-03 - 2022-03-17
#   [retrain] ensemble member 2: fit on 384 rows from range 2022-01-03 - 2022-03-17
# 2023Q3 n=541→ 28 long=+13.72%  comb=+13.72% SPY≈+11.06% sector≈+15.38% alpha=+2.66% sector_alpha=-1.66% IC(Batch)=+0.204
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] ensemble member 0: fit on 395 rows from range 2022-04-04 - 2022-07-01
#   [retrain] ensemble member 1: fit on 446 rows from range 2022-04-04 - 2022-07-01
#   [retrain] ensemble member 2: fit on 387 rows from range 2022-04-04 - 2022-07-01
# 2023Q4 n=544→ 28 long=+6.12%  comb=+6.12% SPY≈+10.82% sector≈+11.36% alpha=-4.70% sector_alpha=-5.23% IC(Batch)=-0.024
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] ensemble member 0: fit on 392 rows from range 2022-07-08 - 2022-09-14
#   [retrain] ensemble member 1: fit on 449 rows from range 2022-07-06 - 2022-09-14
#   [retrain] ensemble member 2: fit on 387 rows from range 2022-07-08 - 2022-09-14
# 2024Q1 n=539→ 27 long=+3.11%  comb=+3.11% SPY≈+4.78% sector≈-1.26% alpha=-1.67% sector_alpha=+4.37% IC(Batch)=-0.002
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] ensemble member 0: fit on 400 rows from range 2022-10-07 - 2022-12-15
#   [retrain] ensemble member 1: fit on 453 rows from range 2022-10-04 - 2022-12-15
#   [retrain] ensemble member 2: fit on 387 rows from range 2022-10-07 - 2022-12-15
# 2024Q2 n=555→ 28 long=+12.17%  comb=+12.17% SPY≈+5.53% sector≈+10.40% alpha=+6.63% sector_alpha=+1.77% IC(Batch)=-0.007
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] ensemble member 0: fit on 404 rows from range 2023-01-05 - 2023-03-17
#   [retrain] ensemble member 1: fit on 455 rows from range 2023-01-05 - 2023-03-17
#   [retrain] ensemble member 2: fit on 393 rows from range 2023-01-05 - 2023-03-17
# 2024Q3 n=560→ 28 long=+10.51%  comb=+10.51% SPY≈+2.49% sector≈+7.10% alpha=+8.02% sector_alpha=+3.42% IC(Batch)=+0.127
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] ensemble member 0: fit on 399 rows from range 2023-04-10 - 2023-07-03
#   [retrain] ensemble member 1: fit on 457 rows from range 2023-04-10 - 2023-07-03
#   [retrain] ensemble member 2: fit on 392 rows from range 2023-04-10 - 2023-07-03
# 2024Q4 n=570→ 29 long=-2.27%  comb=-2.27% SPY≈-4.27% sector≈+3.44% alpha=+2.00% sector_alpha=-5.70% IC(Batch)=+0.102
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] ensemble member 0: fit on 399 rows from range 2023-07-07 - 2023-09-14
#   [retrain] ensemble member 1: fit on 464 rows from range 2023-07-07 - 2023-09-14
#   [retrain] ensemble member 2: fit on 393 rows from range 2023-07-07 - 2023-09-14
# 2025Q1 n=569→ 29 long=+8.57%  comb=+8.57% SPY≈+10.78% sector≈+5.50% alpha=-2.21% sector_alpha=+3.07% IC(Batch)=+0.061
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] ensemble member 0: fit on 406 rows from range 2023-10-06 - 2023-12-15
#   [retrain] ensemble member 1: fit on 470 rows from range 2023-10-06 - 2023-12-15
#   [retrain] ensemble member 2: fit on 398 rows from range 2023-10-06 - 2023-12-15
# 2025Q2 n=576→ 29 long=+5.87%  comb=+5.87% SPY≈+8.12% sector≈+3.20% alpha=-2.25% sector_alpha=+2.67% IC(Batch)=-0.013
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] ensemble member 0: fit on 399 rows from range 2024-01-05 - 2024-03-16
#   [retrain] ensemble member 1: fit on 466 rows from range 2024-01-05 - 2024-03-16
#   [retrain] ensemble member 2: fit on 398 rows from range 2024-01-05 - 2024-03-16
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=577→ 29 long=+3.35%  comb=+3.35% SPY≈+2.67% sector≈+2.03% alpha=+0.69% sector_alpha=+1.32% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] ensemble member 0: fit on 406 rows from range 2024-04-03 - 2024-06-14
#   [retrain] ensemble member 1: fit on 474 rows from range 2024-04-03 - 2024-06-14
#   [retrain] ensemble member 2: fit on 406 rows from range 2024-04-03 - 2024-06-14
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=575→ 29 long=-5.28%  comb=-5.28% SPY≈-4.37% sector≈-9.40% alpha=-0.91% sector_alpha=+4.11% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary ────────────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.0558  (std=0.0751)
#
#   Long leg
#     Mean qtrly return   : +4.79%
#     Annualised Sharpe   : 1.256
#     Win rate            : 75.0%
#     Max drawdown        : -5.28%
#
#   Combined L/S
#     Mean qtrly return   : +4.79%
#     Annualised Sharpe   : 1.256
#     Total return        : +72.23%
#     Max drawdown        : -5.28%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : +0.37%
#     Positive-alpha quarters : 6 / 12 (50.0%)
#
#   Sector benchmark (XLF)
#     Mean qtrly return   : +4.26%
#     Total return        : +61.18%
#
#   Mean sector-level alpha : +0.53%
#     Positive sector-alpha quarters : 8 / 12 (66.7%)
#
# Saved → backtest_results_v2/backtest_full_dataset_fixed_quarterly.csv
# Saved → backtest_results_v2/backtest_full_dataset_fixed_trades.csv
# Plot   → backtest_results_v2/backtest_full_dataset_fixed_plot_returns.png
# Plot   → backtest_results_v2/backtest_full_dataset_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_XGB

EXPERIMENT    = "full_dataset"       # matches results/final_<NAME>_reg.ubj
SECTORS       =  ["technology"]        # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0                # 0 = long-only
REBALANCE     = "fixed"               # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_v2")

df = load_dataset(SECTORS)
START, END = infer_test_window(df)
print(f"Test window: {START}  →  {END}")

results = backtest_XGB.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
    cleanup_sectors = None,
)
# Out:
# Dataset: 20,389 rows | 561 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded ensemble [full_dataset]  (3 models | train IC=0.0775) ICIR=1.0254
# Dataset: 20,389 rows | 561 tickers
# Dataset: 146,809 rows | 3,773 tickers
# [cleanup] fit on global pre-backtest data (91560 rows)
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLK
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] matured start (2021-07-02) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-10-02
# 2023Q1 n=414→ 21 long=+19.88%  comb=+19.88% SPY≈+8.68% sector≈+15.37% alpha=+11.20% sector_alpha=+4.51% IC(Batch)=+0.224
#   [retrain] matured start (2021-09-30) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-12-31
# 2023Q2 n=425→ 22 long=-0.60%  comb=-0.60% SPY≈-3.26% sector≈-4.50% alpha=+2.67% sector_alpha=+3.90% IC(Batch)=+0.272
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] ensemble member 0: fit on 288 rows from range 2022-01-04 - 2022-04-01
#   [retrain] ensemble member 1: fit on 267 rows from range 2022-01-04 - 2022-04-01
#   [retrain] ensemble member 2: fit on 268 rows from range 2022-01-04 - 2022-04-01
# 2023Q3 n=428→ 22 long=+8.64%  comb=+8.64% SPY≈+11.06% sector≈+13.38% alpha=-2.41% sector_alpha=-4.73% IC(Batch)=+0.270
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] ensemble member 0: fit on 312 rows from range 2022-04-05 - 2022-07-01
#   [retrain] ensemble member 1: fit on 304 rows from range 2022-04-05 - 2022-07-01
#   [retrain] ensemble member 2: fit on 301 rows from range 2022-04-05 - 2022-07-01
# 2023Q4 n=445→ 23 long=+4.66%  comb=+4.66% SPY≈+10.82% sector≈+11.61% alpha=-6.16% sector_alpha=-6.95% IC(Batch)=+0.120
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] ensemble member 0: fit on 311 rows from range 2022-07-07 - 2022-09-29
#   [retrain] ensemble member 1: fit on 305 rows from range 2022-07-07 - 2022-09-29
#   [retrain] ensemble member 2: fit on 301 rows from range 2022-07-07 - 2022-09-29
# 2024Q1 n=440→ 22 long=+9.39%  comb=+9.39% SPY≈+4.78% sector≈+9.33% alpha=+4.61% sector_alpha=+0.06% IC(Batch)=+0.206
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] ensemble member 0: fit on 322 rows from range 2022-10-04 - 2022-12-23
#   [retrain] ensemble member 1: fit on 323 rows from range 2022-10-04 - 2022-12-23
#   [retrain] ensemble member 2: fit on 321 rows from range 2022-10-04 - 2022-12-23
# 2024Q2 n=479→ 24 long=+27.85%  comb=+27.85% SPY≈+5.53% sector≈-0.78% alpha=+22.32% sector_alpha=+28.63% IC(Batch)=+0.169
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] ensemble member 0: fit on 328 rows from range 2023-01-03 - 2023-03-31
#   [retrain] ensemble member 1: fit on 332 rows from range 2023-01-03 - 2023-03-31
#   [retrain] ensemble member 2: fit on 326 rows from range 2023-01-03 - 2023-03-31
# 2024Q3 n=499→ 25 long=+47.15%  comb=+47.15% SPY≈+2.49% sector≈+3.16% alpha=+44.66% sector_alpha=+43.98% IC(Batch)=+0.120
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] ensemble member 0: fit on 336 rows from range 2023-04-04 - 2023-06-30
#   [retrain] ensemble member 1: fit on 340 rows from range 2023-04-04 - 2023-06-30
#   [retrain] ensemble member 2: fit on 343 rows from range 2023-04-04 - 2023-06-30
# 2024Q4 n=528→ 27 long=-15.21%  comb=-15.21% SPY≈-4.27% sector≈-11.04% alpha=-10.94% sector_alpha=-4.17% IC(Batch)=+0.097
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] ensemble member 0: fit on 314 rows from range 2023-07-06 - 2023-10-03
#   [retrain] ensemble member 1: fit on 317 rows from range 2023-07-06 - 2023-10-03
#   [retrain] ensemble member 2: fit on 316 rows from range 2023-07-06 - 2023-10-03
# 2025Q1 n=524→ 27 long=+32.05%  comb=+32.05% SPY≈+10.78% sector≈+22.84% alpha=+21.28% sector_alpha=+9.21% IC(Batch)=+0.051
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] ensemble member 0: fit on 299 rows from range 2023-10-03 - 2023-12-26
#   [retrain] ensemble member 1: fit on 316 rows from range 2023-10-03 - 2023-12-26
#   [retrain] ensemble member 2: fit on 302 rows from range 2023-10-03 - 2023-12-26
# 2025Q2 n=543→ 28 long=+14.04%  comb=+14.04% SPY≈+8.12% sector≈+11.45% alpha=+5.92% sector_alpha=+2.59% IC(Batch)=-0.379
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] ensemble member 0: fit on 323 rows from range 2024-01-09 - 2024-03-28
#   [retrain] ensemble member 1: fit on 338 rows from range 2024-01-09 - 2024-03-28
#   [retrain] ensemble member 2: fit on 329 rows from range 2024-01-09 - 2024-03-28
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=544→ 28 long=-6.27%  comb=-6.27% SPY≈+2.67% sector≈+2.31% alpha=-8.94% sector_alpha=-8.58% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] ensemble member 0: fit on 302 rows from range 2024-04-04 - 2024-06-27
#   [retrain] ensemble member 1: fit on 311 rows from range 2024-04-04 - 2024-06-27
#   [retrain] ensemble member 2: fit on 312 rows from range 2024-04-04 - 2024-06-27
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=539→ 27 long=-15.80%  comb=-15.80% SPY≈-4.37% sector≈-7.57% alpha=-11.43% sector_alpha=-8.23% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary ────────────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.1149  (std=0.1886)
#
#   Long leg
#     Mean qtrly return   : +10.48%
#     Annualised Sharpe   : 0.980
#     Win rate            : 66.7%
#     Max drawdown        : -21.08%
#
#   Combined L/S
#     Mean qtrly return   : +10.48%
#     Annualised Sharpe   : 0.980
#     Total return        : +180.97%
#     Max drawdown        : -21.08%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : +6.06%
#     Positive-alpha quarters : 7 / 12 (58.3%)
#
#   Sector benchmark (XLK)
#     Mean qtrly return   : +5.46%
#     Total return        : +79.70%
#
#   Mean sector-level alpha : +5.02%
#     Positive sector-alpha quarters : 7 / 12 (58.3%)
#
# Saved → backtest_results_v2/backtest_full_dataset_fixed_quarterly.csv
# Saved → backtest_results_v2/backtest_full_dataset_fixed_trades.csv
# Plot   → backtest_results_v2/backtest_full_dataset_fixed_plot_returns.png
# Plot   → backtest_results_v2/backtest_full_dataset_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_XGB

EXPERIMENT    = "full_dataset"       # matches results/final_<NAME>_reg.ubj
SECTORS       =  ["industrials"]        # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0                # 0 = long-only
REBALANCE     = "fixed"               # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_v2")

df = load_dataset(SECTORS)
START, END = infer_test_window(df)
print(f"Test window: {START}  →  {END}")

results = backtest_XGB.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
    cleanup_sectors = None,
)
# Out:
# Dataset: 21,971 rows | 493 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded ensemble [full_dataset]  (3 models | train IC=0.0775) ICIR=1.0254
# Dataset: 21,971 rows | 493 tickers
# Dataset: 146,809 rows | 3,773 tickers
# [cleanup] fit on global pre-backtest data (91560 rows)
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLI
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] matured start (2021-07-02) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-10-02
# 2023Q1 n=424→ 22 long=+13.03%  comb=+13.03% SPY≈+8.68% sector≈+6.49% alpha=+4.35% sector_alpha=+6.54% IC(Batch)=+0.257
#   [retrain] matured start (2021-09-30) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-12-31
# 2023Q2 n=434→ 22 long=+2.19%  comb=+2.19% SPY≈-3.26% sector≈-6.08% alpha=+5.45% sector_alpha=+8.27% IC(Batch)=+0.189
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] ensemble member 0: fit on 346 rows from range 2022-01-05 - 2022-04-01
#   [retrain] ensemble member 1: fit on 334 rows from range 2022-01-05 - 2022-04-01
#   [retrain] ensemble member 2: fit on 334 rows from range 2022-01-05 - 2022-04-01
# 2023Q3 n=431→ 22 long=+11.52%  comb=+11.52% SPY≈+11.06% sector≈+13.02% alpha=+0.46% sector_alpha=-1.50% IC(Batch)=+0.196
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] ensemble member 0: fit on 359 rows from range 2022-04-05 - 2022-07-01
#   [retrain] ensemble member 1: fit on 356 rows from range 2022-04-05 - 2022-07-01
#   [retrain] ensemble member 2: fit on 359 rows from range 2022-04-05 - 2022-07-01
# 2023Q4 n=435→ 22 long=+10.19%  comb=+10.19% SPY≈+10.82% sector≈+11.11% alpha=-0.63% sector_alpha=-0.92% IC(Batch)=+0.137
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] ensemble member 0: fit on 353 rows from range 2022-07-07 - 2022-09-30
#   [retrain] ensemble member 1: fit on 346 rows from range 2022-07-08 - 2022-09-30
#   [retrain] ensemble member 2: fit on 345 rows from range 2022-07-07 - 2022-09-30
# 2024Q1 n=441→ 23 long=-7.72%  comb=-7.72% SPY≈+4.78% sector≈-3.21% alpha=-12.49% sector_alpha=-4.50% IC(Batch)=+0.094
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] ensemble member 0: fit on 350 rows from range 2022-10-03 - 2022-12-29
#   [retrain] ensemble member 1: fit on 348 rows from range 2022-10-03 - 2022-12-29
#   [retrain] ensemble member 2: fit on 353 rows from range 2022-10-03 - 2022-12-29
# 2024Q2 n=454→ 23 long=+13.98%  comb=+13.98% SPY≈+5.53% sector≈+12.71% alpha=+8.45% sector_alpha=+1.27% IC(Batch)=+0.024
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] ensemble member 0: fit on 356 rows from range 2023-01-05 - 2023-03-30
#   [retrain] ensemble member 1: fit on 355 rows from range 2023-01-05 - 2023-03-30
#   [retrain] ensemble member 2: fit on 353 rows from range 2023-01-05 - 2023-03-30
# 2024Q3 n=463→ 24 long=-4.34%  comb=-4.34% SPY≈+2.49% sector≈-2.23% alpha=-6.83% sector_alpha=-2.11% IC(Batch)=-0.009
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] ensemble member 0: fit on 361 rows from range 2023-04-04 - 2023-06-29
#   [retrain] ensemble member 1: fit on 368 rows from range 2023-04-04 - 2023-06-29
#   [retrain] ensemble member 2: fit on 364 rows from range 2023-04-04 - 2023-06-29
# 2024Q4 n=463→ 24 long=-10.97%  comb=-10.97% SPY≈-4.27% sector≈-0.22% alpha=-6.71% sector_alpha=-10.76% IC(Batch)=-0.044
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] ensemble member 0: fit on 351 rows from range 2023-07-05 - 2023-09-28
#   [retrain] ensemble member 1: fit on 351 rows from range 2023-07-05 - 2023-09-28
#   [retrain] ensemble member 2: fit on 351 rows from range 2023-07-05 - 2023-09-28
# 2025Q1 n=468→ 24 long=+11.60%  comb=+11.60% SPY≈+10.78% sector≈+12.89% alpha=+0.82% sector_alpha=-1.29% IC(Batch)=-0.010
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] ensemble member 0: fit on 349 rows from range 2023-10-04 - 2023-12-22
#   [retrain] ensemble member 1: fit on 355 rows from range 2023-10-04 - 2023-12-22
#   [retrain] ensemble member 2: fit on 350 rows from range 2023-10-04 - 2023-12-22
# 2025Q2 n=472→ 24 long=+11.38%  comb=+11.38% SPY≈+8.12% sector≈+4.98% alpha=+3.26% sector_alpha=+6.40% IC(Batch)=+0.019
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] ensemble member 0: fit on 354 rows from range 2024-01-03 - 2024-03-28
#   [retrain] ensemble member 1: fit on 364 rows from range 2024-01-03 - 2024-03-28
#   [retrain] ensemble member 2: fit on 359 rows from range 2024-01-03 - 2024-03-28
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=469→ 24 long=-4.00%  comb=-4.00% SPY≈+2.67% sector≈+0.92% alpha=-6.66% sector_alpha=-4.92% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] ensemble member 0: fit on 357 rows from range 2024-04-03 - 2024-07-02
#   [retrain] ensemble member 1: fit on 365 rows from range 2024-04-03 - 2024-07-02
#   [retrain] ensemble member 2: fit on 364 rows from range 2024-04-03 - 2024-07-02
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=473→ 24 long=+6.36%  comb=+6.36% SPY≈-4.37% sector≈+4.55% alpha=+10.73% sector_alpha=+1.80% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary ────────────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.0853  (std=0.1043)
#
#   Long leg
#     Mean qtrly return   : +4.44%
#     Annualised Sharpe   : 0.731
#     Win rate            : 66.7%
#     Max drawdown        : -14.84%
#
#   Combined L/S
#     Mean qtrly return   : +4.44%
#     Annualised Sharpe   : 0.731
#     Total return        : +61.39%
#     Max drawdown        : -14.84%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : +0.02%
#     Positive-alpha quarters : 7 / 12 (58.3%)
#
#   Sector benchmark (XLI)
#     Mean qtrly return   : +4.58%
#     Total return        : +67.16%
#
#   Mean sector-level alpha : -0.14%
#     Positive sector-alpha quarters : 5 / 12 (41.7%)
#
# Saved → backtest_results_v2/backtest_full_dataset_fixed_quarterly.csv
# Saved → backtest_results_v2/backtest_full_dataset_fixed_trades.csv
# Plot   → backtest_results_v2/backtest_full_dataset_fixed_plot_returns.png
# Plot   → backtest_results_v2/backtest_full_dataset_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_XGB

EXPERIMENT    = "full_dataset"       # matches results/final_<NAME>_reg.ubj
SECTORS       =  ["healthcare"]        # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0                # 0 = long-only
REBALANCE     = "fixed"               # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_v2")

df = load_dataset(SECTORS)
START, END = infer_test_window(df)
print(f"Test window: {START}  →  {END}")

results = backtest_XGB.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
    cleanup_sectors = None,
)
# Out:
# Dataset: 19,278 rows | 670 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded ensemble [full_dataset]  (3 models | train IC=0.0775) ICIR=1.0254
# Dataset: 19,278 rows | 670 tickers
# Dataset: 146,809 rows | 3,773 tickers
# [cleanup] fit on global pre-backtest data (91560 rows)
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLV
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] matured start (2021-07-02) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-10-02
# 2023Q1 n=446→ 23 long=+31.32%  comb=+31.32% SPY≈+8.68% sector≈+2.95% alpha=+22.64% sector_alpha=+28.37% IC(Batch)=+0.374
#   [retrain] matured start (2021-09-30) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-12-31
# 2023Q2 n=440→ 22 long=-1.38%  comb=-1.38% SPY≈-3.26% sector≈-2.74% alpha=+1.88% sector_alpha=+1.36% IC(Batch)=+0.282
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] ensemble member 0: fit on 269 rows from range 2022-01-07 - 2022-04-01
#   [retrain] ensemble member 1: fit on 247 rows from range 2022-01-07 - 2022-03-16
#   [retrain] ensemble member 2: fit on 244 rows from range 2022-01-07 - 2022-03-16
# 2023Q3 n=450→ 23 long=+31.82%  comb=+31.82% SPY≈+11.06% sector≈+8.43% alpha=+20.76% sector_alpha=+23.39% IC(Batch)=+0.268
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] ensemble member 0: fit on 290 rows from range 2022-04-07 - 2022-06-23
#   [retrain] ensemble member 1: fit on 293 rows from range 2022-04-07 - 2022-06-23
#   [retrain] ensemble member 2: fit on 290 rows from range 2022-04-07 - 2022-06-23
# 2023Q4 n=459→ 23 long=+16.80%  comb=+16.80% SPY≈+10.82% sector≈+5.92% alpha=+5.98% sector_alpha=+10.88% IC(Batch)=+0.150
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] ensemble member 0: fit on 285 rows from range 2022-07-08 - 2022-09-13
#   [retrain] ensemble member 1: fit on 291 rows from range 2022-07-20 - 2022-09-08
#   [retrain] ensemble member 2: fit on 286 rows from range 2022-07-11 - 2022-09-13
# 2024Q1 n=502→ 26 long=-3.86%  comb=-3.86% SPY≈+4.78% sector≈-0.66% alpha=-8.64% sector_alpha=-3.20% IC(Batch)=+0.147
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] ensemble member 0: fit on 289 rows from range 2022-10-07 - 2022-12-21
#   [retrain] ensemble member 1: fit on 297 rows from range 2022-10-07 - 2022-12-21
#   [retrain] ensemble member 2: fit on 293 rows from range 2022-10-07 - 2022-12-21
# 2024Q2 n=495→ 25 long=+7.57%  comb=+7.57% SPY≈+5.53% sector≈+6.67% alpha=+2.03% sector_alpha=+0.90% IC(Batch)=+0.300
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] ensemble member 0: fit on 294 rows from range 2023-01-06 - 2023-03-31
#   [retrain] ensemble member 1: fit on 299 rows from range 2023-01-06 - 2023-03-31
#   [retrain] ensemble member 2: fit on 295 rows from range 2023-01-06 - 2023-03-31
# 2024Q3 n=523→ 27 long=+7.17%  comb=+7.17% SPY≈+2.49% sector≈-10.28% alpha=+4.68% sector_alpha=+17.45% IC(Batch)=+0.146
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] ensemble member 0: fit on 291 rows from range 2023-04-07 - 2023-06-22
#   [retrain] ensemble member 1: fit on 312 rows from range 2023-04-07 - 2023-06-22
#   [retrain] ensemble member 2: fit on 305 rows from range 2023-04-04 - 2023-06-22
# 2024Q4 n=545→ 28 long=-16.16%  comb=-16.16% SPY≈-4.27% sector≈+6.55% alpha=-11.90% sector_alpha=-22.71% IC(Batch)=+0.097
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] ensemble member 0: fit on 273 rows from range 2023-07-07 - 2023-09-07
#   [retrain] ensemble member 1: fit on 281 rows from range 2023-07-07 - 2023-09-07
#   [retrain] ensemble member 2: fit on 277 rows from range 2023-07-07 - 2023-09-13
# 2025Q1 n=569→ 29 long=+34.24%  comb=+34.24% SPY≈+10.78% sector≈-7.24% alpha=+23.47% sector_alpha=+41.49% IC(Batch)=+0.124
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] ensemble member 0: fit on 269 rows from range 2023-10-04 - 2023-12-20
#   [retrain] ensemble member 1: fit on 280 rows from range 2023-10-04 - 2023-12-20
#   [retrain] ensemble member 2: fit on 265 rows from range 2023-10-04 - 2023-12-20
# 2025Q2 n=558→ 28 long=+29.04%  comb=+29.04% SPY≈+8.12% sector≈+3.72% alpha=+20.92% sector_alpha=+25.32% IC(Batch)=+0.432
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] ensemble member 0: fit on 297 rows from range 2024-01-08 - 2024-03-22
#   [retrain] ensemble member 1: fit on 326 rows from range 2024-01-08 - 2024-03-22
#   [retrain] ensemble member 2: fit on 293 rows from range 2024-01-08 - 2024-03-22
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=558→ 28 long=+4.86%  comb=+4.86% SPY≈+2.67% sector≈+11.70% alpha=+2.20% sector_alpha=-6.84% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] ensemble member 0: fit on 268 rows from range 2024-04-09 - 2024-06-20
#   [retrain] ensemble member 1: fit on 295 rows from range 2024-04-09 - 2024-06-20
#   [retrain] ensemble member 2: fit on 274 rows from range 2024-04-09 - 2024-06-20
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=552→ 28 long=-8.73%  comb=-8.73% SPY≈-4.37% sector≈-4.90% alpha=-4.36% sector_alpha=-3.83% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary ────────────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.2320  (std=0.1155)
#
#   Long leg
#     Mean qtrly return   : +11.06%
#     Annualised Sharpe   : 1.143
#     Win rate            : 66.7%
#     Max drawdown        : -16.16%
#
#   Combined L/S
#     Mean qtrly return   : +11.06%
#     Annualised Sharpe   : 1.143
#     Total return        : +207.17%
#     Max drawdown        : -16.16%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : +6.64%
#     Positive-alpha quarters : 9 / 12 (75.0%)
#
#   Sector benchmark (XLV)
#     Mean qtrly return   : +1.68%
#     Total return        : +19.05%
#
#   Mean sector-level alpha : +9.38%
#     Positive sector-alpha quarters : 8 / 12 (66.7%)
#
# Saved → backtest_results_v2/backtest_full_dataset_fixed_quarterly.csv
# Saved → backtest_results_v2/backtest_full_dataset_fixed_trades.csv
# Plot   → backtest_results_v2/backtest_full_dataset_fixed_plot_returns.png
# Plot   → backtest_results_v2/backtest_full_dataset_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_MLP

EXPERIMENT    = "full_dataset"       # matches results_mlp/final_<NAME>_mlp_*.joblib
SECTORS       = ["financial_services"]         # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0.0                    # 0 = long-only
REBALANCE     = "fixed"                # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_mlp")

df = load_dataset(SECTORS)
START, END = infer_test_window(df, test_months=24)
print(f"Test window: {START}  →  {END}")

results = backtest_MLP.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
    cleanup_sectors = None,
)
# Out:
# Dataset: 25,931 rows | 602 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded MLP ensemble [full_dataset] (3 models, methods=['permutation', 'mutual_info', 'lasso'])
# Loaded MLP ensemble [full_dataset]  (3 models | test IC=0.0662 ICIR=1.1782)
# Dataset: 25,931 rows | 602 tickers
# Dataset: 146,809 rows | 3,773 tickers
# [cleanup] fit on global pre-backtest data (91560 rows)
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLF
# Derived train cutoff (retrain guard): 2021-12-30
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] Skipping 2023Q1: matured window 2021-07-02 -> 2021-10-02 overlaps training date
# 2023Q1 n=533→ 27 long=-4.73%  comb=-4.73% SPY≈+8.68% sector≈+5.32% alpha=-13.41% IC(Batch)=-0.057
#   [retrain] Skipping 2023Q2: matured window 2021-09-30 -> 2021-12-31 overlaps training date
# 2023Q2 n=534→ 27 long=+1.02%  comb=+1.02% SPY≈-3.26% sector≈-2.00% alpha=+4.28% IC(Batch)=+0.026
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] MLP ensemble member 0: fit on 380 rows
#   [retrain] MLP ensemble member 1: fit on 437 rows
#   [retrain] MLP ensemble member 2: fit on 395 rows
# 2023Q3 n=541→ 28 long=+22.33%  comb=+22.33% SPY≈+11.06% sector≈+15.38% alpha=+11.28% IC(Batch)=+0.049
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] MLP ensemble member 0: fit on 386 rows
#   [retrain] MLP ensemble member 1: fit on 453 rows
#   [retrain] MLP ensemble member 2: fit on 393 rows
# 2023Q4 n=544→ 28 long=+10.39%  comb=+10.39% SPY≈+10.82% sector≈+11.36% alpha=-0.43% IC(Batch)=+0.008
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] MLP ensemble member 0: fit on 392 rows
#   [retrain] MLP ensemble member 1: fit on 448 rows
#   [retrain] MLP ensemble member 2: fit on 398 rows
# 2024Q1 n=539→ 27 long=-1.53%  comb=-1.53% SPY≈+4.78% sector≈-1.26% alpha=-6.31% IC(Batch)=-0.041
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] MLP ensemble member 0: fit on 387 rows
#   [retrain] MLP ensemble member 1: fit on 462 rows
#   [retrain] MLP ensemble member 2: fit on 412 rows
# 2024Q2 n=555→ 28 long=+8.31%  comb=+8.31% SPY≈+5.53% sector≈+10.40% alpha=+2.78% IC(Batch)=-0.022
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] MLP ensemble member 0: fit on 387 rows
#   [retrain] MLP ensemble member 1: fit on 470 rows
#   [retrain] MLP ensemble member 2: fit on 407 rows
# 2024Q3 n=560→ 28 long=+3.79%  comb=+3.79% SPY≈+2.49% sector≈+7.10% alpha=+1.30% IC(Batch)=+0.100
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] MLP ensemble member 0: fit on 390 rows
#   [retrain] MLP ensemble member 1: fit on 473 rows
#   [retrain] MLP ensemble member 2: fit on 411 rows
# 2024Q4 n=570→ 29 long=+1.00%  comb=+1.00% SPY≈-4.27% sector≈+3.44% alpha=+5.27% IC(Batch)=+0.091
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] MLP ensemble member 0: fit on 399 rows
#   [retrain] MLP ensemble member 1: fit on 465 rows
#   [retrain] MLP ensemble member 2: fit on 409 rows
# 2025Q1 n=569→ 29 long=+12.65%  comb=+12.65% SPY≈+10.78% sector≈+5.50% alpha=+1.88% IC(Batch)=+0.015
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] MLP ensemble member 0: fit on 398 rows
#   [retrain] MLP ensemble member 1: fit on 467 rows
#   [retrain] MLP ensemble member 2: fit on 415 rows
# 2025Q2 n=576→ 29 long=+14.09%  comb=+14.09% SPY≈+8.12% sector≈+3.20% alpha=+5.97% IC(Batch)=-0.105
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] MLP ensemble member 0: fit on 397 rows
#   [retrain] MLP ensemble member 1: fit on 472 rows
#   [retrain] MLP ensemble member 2: fit on 409 rows
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=577→ 29 long=-0.42%  comb=-0.42% SPY≈+2.67% sector≈+2.03% alpha=-3.08% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] MLP ensemble member 0: fit on 401 rows
#   [retrain] MLP ensemble member 1: fit on 478 rows
#   [retrain] MLP ensemble member 2: fit on 422 rows
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=575→ 29 long=-5.25%  comb=-5.25% SPY≈-4.37% sector≈-9.40% alpha=-0.88% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary (MLP) ──────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.0063  (std=0.0647)
#
#   Long leg
#     Mean qtrly return   : +5.14%
#     Annualised Sharpe   : 0.948
#     Win rate            : 66.7%
#     Max drawdown        : -5.64%
#
#   Combined L/S
#     Mean qtrly return   : +5.14%
#     Annualised Sharpe   : 0.948
#     Total return        : +76.20%
#     Max drawdown        : -5.64%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : +0.72%
#     Positive-alpha quarters : 7 / 12 (58.3%)
#
#   Sector benchmark (XLF)
#     Mean qtrly return   : +4.26%
#     Total return        : +61.18%
#
#   Mean sector-level alpha : +0.88%
#     Positive sector-alpha quarters : 5 / 12 (41.7%)
#
# Saved → backtest_results_mlp/backtest_mlp_full_dataset_fixed_quarterly.csv
# Saved → backtest_results_mlp/backtest_mlp_full_dataset_fixed_trades.csv
# Plot   → backtest_results_mlp/backtest_mlp_full_dataset_fixed_plot_returns.png
# Plot   → backtest_results_mlp/backtest_mlp_full_dataset_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_MLP

EXPERIMENT    = "full_dataset"       # matches results_mlp/final_<NAME>_mlp_*.joblib
SECTORS       = ["technology"]         # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0.0                    # 0 = long-only
REBALANCE     = "fixed"                # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_mlp")

df = load_dataset(SECTORS)
START, END = infer_test_window(df, test_months=24)
print(f"Test window: {START}  →  {END}")

results = backtest_MLP.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
    cleanup_sectors = None,
)
# Out:
# Dataset: 20,389 rows | 561 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded MLP ensemble [full_dataset] (3 models, methods=['permutation', 'mutual_info', 'lasso'])
# Loaded MLP ensemble [full_dataset]  (3 models | test IC=0.0662 ICIR=1.1782)
# Dataset: 20,389 rows | 561 tickers
# Dataset: 146,809 rows | 3,773 tickers
# [cleanup] fit on global pre-backtest data (91560 rows)
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLK
# Derived train cutoff (retrain guard): 2021-12-30
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] Skipping 2023Q1: matured window 2021-07-02 -> 2021-10-02 overlaps training date
# 2023Q1 n=414→ 21 long=+8.52%  comb=+8.52% SPY≈+8.68% sector≈+15.37% alpha=-0.16% IC(Batch)=+0.179
#   [retrain] Skipping 2023Q2: matured window 2021-09-30 -> 2021-12-31 overlaps training date
# 2023Q2 n=425→ 22 long=-3.59%  comb=-3.59% SPY≈-3.26% sector≈-4.50% alpha=-0.33% IC(Batch)=+0.160
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] MLP ensemble member 0: fit on 287 rows
#   [retrain] MLP ensemble member 1: fit on 267 rows
#   [retrain] MLP ensemble member 2: fit on 306 rows
# 2023Q3 n=428→ 22 long=+13.37%  comb=+13.37% SPY≈+11.06% sector≈+13.38% alpha=+2.31% IC(Batch)=+0.209
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] MLP ensemble member 0: fit on 306 rows
#   [retrain] MLP ensemble member 1: fit on 306 rows
#   [retrain] MLP ensemble member 2: fit on 315 rows
# 2023Q4 n=445→ 23 long=+12.20%  comb=+12.20% SPY≈+10.82% sector≈+11.61% alpha=+1.38% IC(Batch)=+0.154
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] MLP ensemble member 0: fit on 312 rows
#   [retrain] MLP ensemble member 1: fit on 314 rows
#   [retrain] MLP ensemble member 2: fit on 320 rows
# 2024Q1 n=440→ 22 long=+1.30%  comb=+1.30% SPY≈+4.78% sector≈+9.33% alpha=-3.47% IC(Batch)=+0.091
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] MLP ensemble member 0: fit on 316 rows
#   [retrain] MLP ensemble member 1: fit on 335 rows
#   [retrain] MLP ensemble member 2: fit on 330 rows
# 2024Q2 n=479→ 24 long=+6.19%  comb=+6.19% SPY≈+5.53% sector≈-0.78% alpha=+0.66% IC(Batch)=+0.062
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] MLP ensemble member 0: fit on 320 rows
#   [retrain] MLP ensemble member 1: fit on 339 rows
#   [retrain] MLP ensemble member 2: fit on 341 rows
# 2024Q3 n=499→ 25 long=-0.97%  comb=-0.97% SPY≈+2.49% sector≈+3.16% alpha=-3.46% IC(Batch)=+0.025
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] MLP ensemble member 0: fit on 324 rows
#   [retrain] MLP ensemble member 1: fit on 350 rows
#   [retrain] MLP ensemble member 2: fit on 367 rows
# 2024Q4 n=528→ 27 long=-7.01%  comb=-7.01% SPY≈-4.27% sector≈-11.04% alpha=-2.74% IC(Batch)=+0.017
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] MLP ensemble member 0: fit on 304 rows
#   [retrain] MLP ensemble member 1: fit on 319 rows
#   [retrain] MLP ensemble member 2: fit on 322 rows
# 2025Q1 n=524→ 27 long=+13.86%  comb=+13.86% SPY≈+10.78% sector≈+22.84% alpha=+3.08% IC(Batch)=+0.055
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] MLP ensemble member 0: fit on 294 rows
#   [retrain] MLP ensemble member 1: fit on 326 rows
#   [retrain] MLP ensemble member 2: fit on 319 rows
# 2025Q2 n=543→ 28 long=-0.90%  comb=-0.90% SPY≈+8.12% sector≈+11.45% alpha=-9.02% IC(Batch)=-0.154
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] MLP ensemble member 0: fit on 309 rows
#   [retrain] MLP ensemble member 1: fit on 349 rows
#   [retrain] MLP ensemble member 2: fit on 344 rows
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=544→ 28 long=+0.13%  comb=+0.13% SPY≈+2.67% sector≈+2.31% alpha=-2.54% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] MLP ensemble member 0: fit on 290 rows
#   [retrain] MLP ensemble member 1: fit on 331 rows
#   [retrain] MLP ensemble member 2: fit on 318 rows
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=539→ 27 long=-7.09%  comb=-7.09% SPY≈-4.37% sector≈-7.57% alpha=-2.72% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary (MLP) ──────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.0799  (std=0.1059)
#
#   Long leg
#     Mean qtrly return   : +3.00%
#     Annualised Sharpe   : 0.489
#     Win rate            : 58.3%
#     Max drawdown        : -7.91%
#
#   Combined L/S
#     Mean qtrly return   : +3.00%
#     Annualised Sharpe   : 0.489
#     Total return        : +38.38%
#     Max drawdown        : -7.91%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : -1.42%
#     Positive-alpha quarters : 4 / 12 (33.3%)
#
#   Sector benchmark (XLK)
#     Mean qtrly return   : +5.46%
#     Total return        : +79.70%
#
#   Mean sector-level alpha : -2.46%
#     Positive sector-alpha quarters : 5 / 12 (41.7%)
#
# Saved → backtest_results_mlp/backtest_mlp_full_dataset_fixed_quarterly.csv
# Saved → backtest_results_mlp/backtest_mlp_full_dataset_fixed_trades.csv
# Plot   → backtest_results_mlp/backtest_mlp_full_dataset_fixed_plot_returns.png
# Plot   → backtest_results_mlp/backtest_mlp_full_dataset_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_MLP

EXPERIMENT    = "full_dataset"       # matches results_mlp/final_<NAME>_mlp_*.joblib
SECTORS       = ["industrials"]         # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0.0                    # 0 = long-only
REBALANCE     = "fixed"                # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_mlp")

df = load_dataset(SECTORS)
START, END = infer_test_window(df, test_months=24)
print(f"Test window: {START}  →  {END}")

results = backtest_MLP.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
    cleanup_sectors = None,
)
# Out:
# Dataset: 21,971 rows | 493 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded MLP ensemble [full_dataset] (3 models, methods=['permutation', 'mutual_info', 'lasso'])
# Loaded MLP ensemble [full_dataset]  (3 models | test IC=0.0662 ICIR=1.1782)
# Dataset: 21,971 rows | 493 tickers
# Dataset: 146,809 rows | 3,773 tickers
# [cleanup] fit on global pre-backtest data (91560 rows)
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLI
# Derived train cutoff (retrain guard): 2021-12-30
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] Skipping 2023Q1: matured window 2021-07-02 -> 2021-10-02 overlaps training date
# 2023Q1 n=424→ 22 long=+8.48%  comb=+8.48% SPY≈+8.68% sector≈+6.49% alpha=-0.20% IC(Batch)=+0.177
#   [retrain] Skipping 2023Q2: matured window 2021-09-30 -> 2021-12-31 overlaps training date
# 2023Q2 n=434→ 22 long=-4.79%  comb=-4.79% SPY≈-3.26% sector≈-6.08% alpha=-1.52% IC(Batch)=+0.137
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] MLP ensemble member 0: fit on 334 rows
#   [retrain] MLP ensemble member 1: fit on 334 rows
#   [retrain] MLP ensemble member 2: fit on 345 rows
# 2023Q3 n=431→ 22 long=+14.84%  comb=+14.84% SPY≈+11.06% sector≈+13.02% alpha=+3.78% IC(Batch)=+0.204
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] MLP ensemble member 0: fit on 332 rows
#   [retrain] MLP ensemble member 1: fit on 352 rows
#   [retrain] MLP ensemble member 2: fit on 357 rows
# 2023Q4 n=435→ 22 long=+9.44%  comb=+9.44% SPY≈+10.82% sector≈+11.11% alpha=-1.38% IC(Batch)=+0.138
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] MLP ensemble member 0: fit on 345 rows
#   [retrain] MLP ensemble member 1: fit on 348 rows
#   [retrain] MLP ensemble member 2: fit on 366 rows
# 2024Q1 n=441→ 23 long=-5.90%  comb=-5.90% SPY≈+4.78% sector≈-3.21% alpha=-10.67% IC(Batch)=+0.117
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] MLP ensemble member 0: fit on 343 rows
#   [retrain] MLP ensemble member 1: fit on 361 rows
#   [retrain] MLP ensemble member 2: fit on 356 rows
# 2024Q2 n=454→ 23 long=+17.54%  comb=+17.54% SPY≈+5.53% sector≈+12.71% alpha=+12.01% IC(Batch)=+0.094
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] MLP ensemble member 0: fit on 353 rows
#   [retrain] MLP ensemble member 1: fit on 364 rows
#   [retrain] MLP ensemble member 2: fit on 357 rows
# 2024Q3 n=463→ 24 long=-0.20%  comb=-0.20% SPY≈+2.49% sector≈-2.23% alpha=-2.69% IC(Batch)=+0.062
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] MLP ensemble member 0: fit on 351 rows
#   [retrain] MLP ensemble member 1: fit on 382 rows
#   [retrain] MLP ensemble member 2: fit on 374 rows
# 2024Q4 n=463→ 24 long=-6.80%  comb=-6.80% SPY≈-4.27% sector≈-0.22% alpha=-2.54% IC(Batch)=+0.103
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] MLP ensemble member 0: fit on 340 rows
#   [retrain] MLP ensemble member 1: fit on 370 rows
#   [retrain] MLP ensemble member 2: fit on 363 rows
# 2025Q1 n=468→ 24 long=+13.14%  comb=+13.14% SPY≈+10.78% sector≈+12.89% alpha=+2.37% IC(Batch)=+0.126
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] MLP ensemble member 0: fit on 334 rows
#   [retrain] MLP ensemble member 1: fit on 364 rows
#   [retrain] MLP ensemble member 2: fit on 352 rows
# 2025Q2 n=472→ 24 long=+1.13%  comb=+1.13% SPY≈+8.12% sector≈+4.98% alpha=-6.99% IC(Batch)=+0.038
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] MLP ensemble member 0: fit on 335 rows
#   [retrain] MLP ensemble member 1: fit on 370 rows
#   [retrain] MLP ensemble member 2: fit on 371 rows
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=469→ 24 long=-2.26%  comb=-2.26% SPY≈+2.67% sector≈+0.92% alpha=-4.92% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] MLP ensemble member 0: fit on 340 rows
#   [retrain] MLP ensemble member 1: fit on 375 rows
#   [retrain] MLP ensemble member 2: fit on 360 rows
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=473→ 24 long=+3.79%  comb=+3.79% SPY≈-4.37% sector≈+4.55% alpha=+8.16% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary (MLP) ──────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.1196  (std=0.0494)
#
#   Long leg
#     Mean qtrly return   : +4.04%
#     Annualised Sharpe   : 0.683
#     Win rate            : 58.3%
#     Max drawdown        : -6.98%
#
#   Combined L/S
#     Mean qtrly return   : +4.04%
#     Annualised Sharpe   : 0.683
#     Total return        : +55.03%
#     Max drawdown        : -6.98%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : -0.38%
#     Positive-alpha quarters : 4 / 12 (33.3%)
#
#   Sector benchmark (XLI)
#     Mean qtrly return   : +4.58%
#     Total return        : +67.16%
#
#   Mean sector-level alpha : -0.54%
#     Positive sector-alpha quarters : 6 / 12 (50.0%)
#
# Saved → backtest_results_mlp/backtest_mlp_full_dataset_fixed_quarterly.csv
# Saved → backtest_results_mlp/backtest_mlp_full_dataset_fixed_trades.csv
# Plot   → backtest_results_mlp/backtest_mlp_full_dataset_fixed_plot_returns.png
# Plot   → backtest_results_mlp/backtest_mlp_full_dataset_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_MLP

EXPERIMENT    = "full_dataset"       # matches results_mlp/final_<NAME>_mlp_*.joblib
SECTORS       = ["healthcare"]         # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0.0                    # 0 = long-only
REBALANCE     = "fixed"                # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_mlp")

df = load_dataset(SECTORS)
START, END = infer_test_window(df, test_months=24)
print(f"Test window: {START}  →  {END}")

results = backtest_MLP.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
    cleanup_sectors = None,
)
# Out:
# Dataset: 19,278 rows | 670 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded MLP ensemble [full_dataset] (3 models, methods=['permutation', 'mutual_info', 'lasso'])
# Loaded MLP ensemble [full_dataset]  (3 models | test IC=0.0662 ICIR=1.1782)
# Dataset: 19,278 rows | 670 tickers
# Dataset: 146,809 rows | 3,773 tickers
# [cleanup] fit on global pre-backtest data (91560 rows)
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLV
# Derived train cutoff (retrain guard): 2021-12-30
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] Skipping 2023Q1: matured window 2021-07-02 -> 2021-10-02 overlaps training date
# 2023Q1 n=446→ 23 long=+16.54%  comb=+16.54% SPY≈+8.68% sector≈+2.95% alpha=+7.86% IC(Batch)=+0.290
#   [retrain] Skipping 2023Q2: matured window 2021-09-30 -> 2021-12-31 overlaps training date
# 2023Q2 n=440→ 22 long=-11.65%  comb=-11.65% SPY≈-3.26% sector≈-2.74% alpha=-8.39% IC(Batch)=+0.224
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] MLP ensemble member 0: fit on 260 rows
#   [retrain] MLP ensemble member 1: fit on 240 rows
#   [retrain] MLP ensemble member 2: fit on 291 rows
# 2023Q3 n=450→ 23 long=+8.13%  comb=+8.13% SPY≈+11.06% sector≈+8.43% alpha=-2.93% IC(Batch)=+0.211
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] MLP ensemble member 0: fit on 279 rows
#   [retrain] MLP ensemble member 1: fit on 297 rows
#   [retrain] MLP ensemble member 2: fit on 292 rows
# 2023Q4 n=459→ 23 long=+9.15%  comb=+9.15% SPY≈+10.82% sector≈+5.92% alpha=-1.67% IC(Batch)=+0.160
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] MLP ensemble member 0: fit on 287 rows
#   [retrain] MLP ensemble member 1: fit on 301 rows
#   [retrain] MLP ensemble member 2: fit on 301 rows
# 2024Q1 n=502→ 26 long=-8.46%  comb=-8.46% SPY≈+4.78% sector≈-0.66% alpha=-13.23% IC(Batch)=+0.178
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] MLP ensemble member 0: fit on 293 rows
#   [retrain] MLP ensemble member 1: fit on 314 rows
#   [retrain] MLP ensemble member 2: fit on 305 rows
# 2024Q2 n=495→ 25 long=+12.96%  comb=+12.96% SPY≈+5.53% sector≈+6.67% alpha=+7.43% IC(Batch)=+0.307
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] MLP ensemble member 0: fit on 297 rows
#   [retrain] MLP ensemble member 1: fit on 322 rows
#   [retrain] MLP ensemble member 2: fit on 321 rows
# 2024Q3 n=523→ 27 long=-0.71%  comb=-0.71% SPY≈+2.49% sector≈-10.28% alpha=-3.20% IC(Batch)=+0.191
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] MLP ensemble member 0: fit on 283 rows
#   [retrain] MLP ensemble member 1: fit on 317 rows
#   [retrain] MLP ensemble member 2: fit on 346 rows
# 2024Q4 n=545→ 28 long=+0.20%  comb=+0.20% SPY≈-4.27% sector≈+6.55% alpha=+4.47% IC(Batch)=+0.082
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] MLP ensemble member 0: fit on 274 rows
#   [retrain] MLP ensemble member 1: fit on 296 rows
#   [retrain] MLP ensemble member 2: fit on 303 rows
# 2025Q1 n=569→ 29 long=+1.12%  comb=+1.12% SPY≈+10.78% sector≈-7.24% alpha=-9.66% IC(Batch)=+0.103
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] MLP ensemble member 0: fit on 256 rows
#   [retrain] MLP ensemble member 1: fit on 289 rows
#   [retrain] MLP ensemble member 2: fit on 274 rows
# 2025Q2 n=558→ 28 long=+5.34%  comb=+5.34% SPY≈+8.12% sector≈+3.72% alpha=-2.79% IC(Batch)=+0.168
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] MLP ensemble member 0: fit on 286 rows
#   [retrain] MLP ensemble member 1: fit on 343 rows
#   [retrain] MLP ensemble member 2: fit on 329 rows
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=558→ 28 long=+10.91%  comb=+10.91% SPY≈+2.67% sector≈+11.70% alpha=+8.25% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] MLP ensemble member 0: fit on 263 rows
#   [retrain] MLP ensemble member 1: fit on 309 rows
#   [retrain] MLP ensemble member 2: fit on 279 rows
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=552→ 28 long=-14.21%  comb=-14.21% SPY≈-4.37% sector≈-4.90% alpha=-9.84% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary (MLP) ──────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.1912  (std=0.0715)
#
#   Long leg
#     Mean qtrly return   : +2.44%
#     Annualised Sharpe   : 0.262
#     Win rate            : 66.7%
#     Max drawdown        : -14.21%
#
#   Combined L/S
#     Mean qtrly return   : +2.44%
#     Annualised Sharpe   : 0.262
#     Total return        : +26.70%
#     Max drawdown        : -14.21%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : -1.98%
#     Positive-alpha quarters : 4 / 12 (33.3%)
#
#   Sector benchmark (XLV)
#     Mean qtrly return   : +1.68%
#     Total return        : +19.05%
#
#   Mean sector-level alpha : +0.77%
#     Positive sector-alpha quarters : 6 / 12 (50.0%)
#
# Saved → backtest_results_mlp/backtest_mlp_full_dataset_fixed_quarterly.csv
# Saved → backtest_results_mlp/backtest_mlp_full_dataset_fixed_trades.csv
# Plot   → backtest_results_mlp/backtest_mlp_full_dataset_fixed_plot_returns.png
# Plot   → backtest_results_mlp/backtest_mlp_full_dataset_fixed_plot_risk.png
