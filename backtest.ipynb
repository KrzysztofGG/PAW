# %%
from pathlib import Path

from backtest_util import *
import backtest_XGB

EXPERIMENT    = "full_dataset"       # matches results/final_<NAME>_reg.ubj
SECTORS       =  None#[EXPERIMENT]        # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0                # 0 = long-only
REBALANCE     = "fixed"               # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_v2")

df = load_dataset(SECTORS)
START, END = infer_test_window(df)
print(f"Test window: {START}  →  {END}")
# Out:
# GPU detected: NVIDIA GeForce GTX 1070, 8192 MiB
# Dataset: 146,809 rows | 3,773 tickers
# Test window: 2023-03-31  →  2026-03-15

# %%
results = backtest_XGB.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
)
# Out:
# Loaded ensemble [full_dataset]  (3 models | train IC=0.0775) ICIR=1.0254
# Dataset: 146,809 rows | 3,773 tickers
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] matured start (2021-07-02) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-10-02
# 2023Q1 n=3032→152 long=+13.04%  comb=+13.04% SPY≈+8.68%  alpha=+4.36% sector_alpha=+nan% IC(Batch)=+0.167
#   [retrain] matured start (2021-09-30) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-12-31
# 2023Q2 n=3079→154 long=-3.25%  comb=-3.25% SPY≈-3.26%  alpha=+0.02% sector_alpha=+nan% IC(Batch)=+0.156
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] ensemble member 0: fit on 2273 rows from range 2022-01-03 - 2022-04-01
#   [retrain] ensemble member 1: fit on 2262 rows from range 2022-01-03 - 2022-04-01
#   [retrain] ensemble member 2: fit on 2180 rows from range 2022-01-03 - 2022-04-01
# 2023Q3 n=3088→155 long=+14.19%  comb=+14.19% SPY≈+11.06%  alpha=+3.13% sector_alpha=+nan% IC(Batch)=+0.172
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] ensemble member 0: fit on 2352 rows from range 2022-04-04 - 2022-07-01
#   [retrain] ensemble member 1: fit on 2425 rows from range 2022-04-04 - 2022-07-01
#   [retrain] ensemble member 2: fit on 2338 rows from range 2022-04-04 - 2022-07-01
# 2023Q4 n=3136→157 long=+6.40%  comb=+6.40% SPY≈+10.82%  alpha=-4.42% sector_alpha=+nan% IC(Batch)=+0.042
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] ensemble member 0: fit on 2330 rows from range 2022-07-07 - 2022-09-30
#   [retrain] ensemble member 1: fit on 2412 rows from range 2022-07-06 - 2022-09-30
#   [retrain] ensemble member 2: fit on 2315 rows from range 2022-07-07 - 2022-09-30
# 2024Q1 n=3147→158 long=+0.41%  comb=+0.41% SPY≈+4.78%  alpha=-4.36% sector_alpha=+nan% IC(Batch)=+0.059
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] ensemble member 0: fit on 2373 rows from range 2022-10-03 - 2022-12-29
#   [retrain] ensemble member 1: fit on 2462 rows from range 2022-10-03 - 2022-12-29
#   [retrain] ensemble member 2: fit on 2367 rows from range 2022-10-03 - 2022-12-29
# 2024Q2 n=3311→166 long=+14.41%  comb=+14.41% SPY≈+5.53%  alpha=+8.87% sector_alpha=+nan% IC(Batch)=+0.048
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] ensemble member 0: fit on 2408 rows from range 2023-01-03 - 2023-03-31
#   [retrain] ensemble member 1: fit on 2491 rows from range 2023-01-03 - 2023-03-31
#   [retrain] ensemble member 2: fit on 2393 rows from range 2023-01-03 - 2023-03-31
# 2024Q3 n=3371→169 long=+15.01%  comb=+15.01% SPY≈+2.49%  alpha=+12.52% sector_alpha=+nan% IC(Batch)=+0.072
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] ensemble member 0: fit on 2422 rows from range 2023-04-04 - 2023-07-03
#   [retrain] ensemble member 1: fit on 2548 rows from range 2023-04-04 - 2023-07-03
#   [retrain] ensemble member 2: fit on 2450 rows from range 2023-04-04 - 2023-07-03
# 2024Q4 n=3468→174 long=-6.22%  comb=-6.22% SPY≈-4.27%  alpha=-1.96% sector_alpha=+nan% IC(Batch)=+0.071
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] ensemble member 0: fit on 2339 rows from range 2023-07-05 - 2023-10-03
#   [retrain] ensemble member 1: fit on 2448 rows from range 2023-07-05 - 2023-10-03
#   [retrain] ensemble member 2: fit on 2354 rows from range 2023-07-05 - 2023-10-03
# 2025Q1 n=3474→174 long=+11.18%  comb=+11.18% SPY≈+10.78%  alpha=+0.40% sector_alpha=+nan% IC(Batch)=+0.077
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] ensemble member 0: fit on 2327 rows from range 2023-10-03 - 2023-12-26
#   [retrain] ensemble member 1: fit on 2464 rows from range 2023-10-03 - 2023-12-26
#   [retrain] ensemble member 2: fit on 2326 rows from range 2023-10-03 - 2023-12-26
# 2025Q2 n=3547→178 long=+13.18%  comb=+13.18% SPY≈+8.12%  alpha=+5.06% sector_alpha=+nan% IC(Batch)=+0.158
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] ensemble member 0: fit on 2359 rows from range 2024-01-03 - 2024-04-01
#   [retrain] ensemble member 1: fit on 2536 rows from range 2024-01-03 - 2024-04-01
#   [retrain] ensemble member 2: fit on 2386 rows from range 2024-01-03 - 2024-04-01
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=3530→177 long=+0.81%  comb=+0.81% SPY≈+2.67%  alpha=-1.85% sector_alpha=+nan% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] ensemble member 0: fit on 2338 rows from range 2024-04-03 - 2024-07-02
#   [retrain] ensemble member 1: fit on 2517 rows from range 2024-04-03 - 2024-07-02
#   [retrain] ensemble member 2: fit on 2387 rows from range 2024-04-03 - 2024-07-02
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=3510→176 long=-3.75%  comb=-3.75% SPY≈-4.37%  alpha=+0.62% sector_alpha=+nan% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary ────────────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.1022  (std=0.0538)
#
#   Long leg
#     Mean qtrly return   : +6.28%
#     Annualised Sharpe   : 1.263
#     Win rate            : 75.0%
#     Max drawdown        : -6.22%
#
#   Combined L/S
#     Mean qtrly return   : +6.28%
#     Annualised Sharpe   : 1.263
#     Total return        : +101.00%
#     Max drawdown        : -6.22%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : +1.86%
#     Positive-alpha quarters : 8 / 12 (66.7%)
#
# Saved → backtest_results_v2/backtest_full_dataset_fixed_quarterly.csv
# Saved → backtest_results_v2/backtest_full_dataset_fixed_trades.csv
# Plot   → backtest_results_v2/backtest_full_dataset_fixed_plot_returns.png
# Plot   → backtest_results_v2/backtest_full_dataset_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_XGB

EXPERIMENT    = "financial_services"       # matches results/final_<NAME>_reg.ubj
SECTORS       =  [EXPERIMENT]        # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0                # 0 = long-only
REBALANCE     = "fixed"               # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_v2")

df = load_dataset(SECTORS)
START, END = infer_test_window(df)
print(f"Test window: {START}  →  {END}")

results = backtest_XGB.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
)
# Out:
# Dataset: 25,931 rows | 602 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded ensemble [financial_services]  (3 models | train IC=0.0934) ICIR=1.5346
# Dataset: 25,931 rows | 602 tickers
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLF
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] matured start (2021-07-02) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-10-02
# 2023Q1 n=533→ 27 long=+3.05%  comb=+3.05% SPY≈+8.68% sector≈+5.32% alpha=-5.63% sector_alpha=-2.27% IC(Batch)=+0.104
#   [retrain] matured start (2021-09-30) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-12-31
# 2023Q2 n=534→ 27 long=+5.41%  comb=+5.41% SPY≈-3.26% sector≈-2.00% alpha=+8.68% sector_alpha=+7.41% IC(Batch)=+0.150
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] ensemble member 0: fit on 381 rows from range 2022-01-03 - 2022-03-17
#   [retrain] ensemble member 1: fit on 389 rows from range 2022-01-03 - 2022-03-17
#   [retrain] ensemble member 2: fit on 382 rows from range 2022-01-03 - 2022-03-17
# 2023Q3 n=541→ 28 long=+22.05%  comb=+22.05% SPY≈+11.06% sector≈+15.38% alpha=+10.99% sector_alpha=+6.67% IC(Batch)=+0.172
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] ensemble member 0: fit on 388 rows from range 2022-04-04 - 2022-07-01
#   [retrain] ensemble member 1: fit on 387 rows from range 2022-04-04 - 2022-07-01
#   [retrain] ensemble member 2: fit on 392 rows from range 2022-04-04 - 2022-07-01
# 2023Q4 n=544→ 28 long=+4.57%  comb=+4.57% SPY≈+10.82% sector≈+11.36% alpha=-6.25% sector_alpha=-6.79% IC(Batch)=+0.000
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] ensemble member 0: fit on 386 rows from range 2022-07-08 - 2022-09-14
#   [retrain] ensemble member 1: fit on 392 rows from range 2022-07-08 - 2022-09-14
#   [retrain] ensemble member 2: fit on 393 rows from range 2022-07-08 - 2022-09-14
# 2024Q1 n=539→ 27 long=-2.79%  comb=-2.79% SPY≈+4.78% sector≈-1.26% alpha=-7.56% sector_alpha=-1.53% IC(Batch)=+0.048
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] ensemble member 0: fit on 383 rows from range 2022-10-07 - 2022-12-15
#   [retrain] ensemble member 1: fit on 387 rows from range 2022-10-07 - 2022-12-15
#   [retrain] ensemble member 2: fit on 388 rows from range 2022-10-07 - 2022-12-15
# 2024Q2 n=555→ 28 long=+14.73%  comb=+14.73% SPY≈+5.53% sector≈+10.40% alpha=+9.19% sector_alpha=+4.33% IC(Batch)=+0.077
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] ensemble member 0: fit on 392 rows from range 2023-01-05 - 2023-03-17
#   [retrain] ensemble member 1: fit on 398 rows from range 2023-01-05 - 2023-03-17
#   [retrain] ensemble member 2: fit on 391 rows from range 2023-01-05 - 2023-03-17
# 2024Q3 n=560→ 28 long=+11.59%  comb=+11.59% SPY≈+2.49% sector≈+7.10% alpha=+9.10% sector_alpha=+4.49% IC(Batch)=+0.253
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] ensemble member 0: fit on 404 rows from range 2023-04-10 - 2023-07-03
#   [retrain] ensemble member 1: fit on 400 rows from range 2023-04-10 - 2023-07-03
#   [retrain] ensemble member 2: fit on 403 rows from range 2023-04-10 - 2023-07-03
# 2024Q4 n=570→ 29 long=-0.04%  comb=-0.04% SPY≈-4.27% sector≈+3.44% alpha=+4.23% sector_alpha=-3.48% IC(Batch)=+0.130
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] ensemble member 0: fit on 396 rows from range 2023-07-07 - 2023-09-14
#   [retrain] ensemble member 1: fit on 401 rows from range 2023-07-07 - 2023-09-14
#   [retrain] ensemble member 2: fit on 397 rows from range 2023-07-07 - 2023-09-14
# 2025Q1 n=569→ 29 long=+6.92%  comb=+6.92% SPY≈+10.78% sector≈+5.50% alpha=-3.85% sector_alpha=+1.42% IC(Batch)=+0.091
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] ensemble member 0: fit on 400 rows from range 2023-10-06 - 2023-12-15
#   [retrain] ensemble member 1: fit on 402 rows from range 2023-10-06 - 2023-12-15
#   [retrain] ensemble member 2: fit on 397 rows from range 2023-10-06 - 2023-12-15
# 2025Q2 n=576→ 29 long=+6.15%  comb=+6.15% SPY≈+8.12% sector≈+3.20% alpha=-1.97% sector_alpha=+2.95% IC(Batch)=+0.051
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] ensemble member 0: fit on 393 rows from range 2024-01-05 - 2024-03-16
#   [retrain] ensemble member 1: fit on 398 rows from range 2024-01-05 - 2024-03-16
#   [retrain] ensemble member 2: fit on 393 rows from range 2024-01-05 - 2024-03-16
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=577→ 29 long=+3.92%  comb=+3.92% SPY≈+2.67% sector≈+2.03% alpha=+1.26% sector_alpha=+1.90% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] ensemble member 0: fit on 405 rows from range 2024-04-03 - 2024-06-14
#   [retrain] ensemble member 1: fit on 416 rows from range 2024-04-03 - 2024-06-14
#   [retrain] ensemble member 2: fit on 400 rows from range 2024-04-03 - 2024-06-14
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=575→ 29 long=-1.01%  comb=-1.01% SPY≈-4.37% sector≈-9.40% alpha=+3.36% sector_alpha=+8.39% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary ────────────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.1076  (std=0.0721)
#
#   Long leg
#     Mean qtrly return   : +6.21%
#     Annualised Sharpe   : 1.453
#     Win rate            : 75.0%
#     Max drawdown        : -2.79%
#
#   Combined L/S
#     Mean qtrly return   : +6.21%
#     Annualised Sharpe   : 1.453
#     Total return        : +101.39%
#     Max drawdown        : -2.79%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : +1.79%
#     Positive-alpha quarters : 7 / 12 (58.3%)
#
#   Sector benchmark (XLF)
#     Mean qtrly return   : +4.26%
#     Total return        : +61.18%
#
#   Mean sector-level alpha : +1.96%
#     Positive sector-alpha quarters : 8 / 12 (66.7%)
#
# Saved → backtest_results_v2/backtest_financial_services_fixed_quarterly.csv
# Saved → backtest_results_v2/backtest_financial_services_fixed_trades.csv
# Plot   → backtest_results_v2/backtest_financial_services_fixed_plot_returns.png
# Plot   → backtest_results_v2/backtest_financial_services_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_XGB

EXPERIMENT    = "technology"       # matches results/final_<NAME>_reg.ubj
SECTORS       =  [EXPERIMENT]        # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0                # 0 = long-only
REBALANCE     = "fixed"               # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_v2")

df = load_dataset(SECTORS)
START, END = infer_test_window(df)
print(f"Test window: {START}  →  {END}")

results = backtest_XGB.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
)
# Out:
# Dataset: 20,389 rows | 561 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded ensemble [technology]  (3 models | train IC=0.0977) ICIR=0.7292
# Dataset: 20,389 rows | 561 tickers
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLK
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] matured start (2021-07-02) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-10-02
# 2023Q1 n=414→ 21 long=+10.41%  comb=+10.41% SPY≈+8.68% sector≈+15.37% alpha=+1.73% sector_alpha=-4.97% IC(Batch)=+0.237
#   [retrain] matured start (2021-09-30) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-12-31
# 2023Q2 n=425→ 22 long=-9.47%  comb=-9.47% SPY≈-3.26% sector≈-4.50% alpha=-6.21% sector_alpha=-4.97% IC(Batch)=+0.252
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] ensemble member 0: fit on 320 rows from range 2022-01-04 - 2022-04-01
#   [retrain] ensemble member 1: fit on 273 rows from range 2022-01-04 - 2022-04-01
#   [retrain] ensemble member 2: fit on 306 rows from range 2022-01-04 - 2022-04-01
# 2023Q3 n=428→ 22 long=+16.70%  comb=+16.70% SPY≈+11.06% sector≈+13.38% alpha=+5.64% sector_alpha=+3.33% IC(Batch)=+0.280
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] ensemble member 0: fit on 322 rows from range 2022-04-05 - 2022-07-01
#   [retrain] ensemble member 1: fit on 306 rows from range 2022-04-05 - 2022-07-01
#   [retrain] ensemble member 2: fit on 319 rows from range 2022-04-05 - 2022-07-01
# 2023Q4 n=445→ 23 long=+5.96%  comb=+5.96% SPY≈+10.82% sector≈+11.61% alpha=-4.86% sector_alpha=-5.64% IC(Batch)=+0.075
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] ensemble member 0: fit on 323 rows from range 2022-07-07 - 2022-09-29
#   [retrain] ensemble member 1: fit on 310 rows from range 2022-07-07 - 2022-09-29
#   [retrain] ensemble member 2: fit on 314 rows from range 2022-07-07 - 2022-09-29
# 2024Q1 n=440→ 22 long=+3.55%  comb=+3.55% SPY≈+4.78% sector≈+9.33% alpha=-1.23% sector_alpha=-5.78% IC(Batch)=+0.035
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] ensemble member 0: fit on 326 rows from range 2022-10-04 - 2022-12-23
#   [retrain] ensemble member 1: fit on 326 rows from range 2022-10-04 - 2022-12-23
#   [retrain] ensemble member 2: fit on 322 rows from range 2022-10-04 - 2022-12-23
# 2024Q2 n=479→ 24 long=+0.98%  comb=+0.98% SPY≈+5.53% sector≈-0.78% alpha=-4.55% sector_alpha=+1.76% IC(Batch)=+0.035
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] ensemble member 0: fit on 336 rows from range 2023-01-03 - 2023-03-31
#   [retrain] ensemble member 1: fit on 333 rows from range 2023-01-03 - 2023-03-31
#   [retrain] ensemble member 2: fit on 335 rows from range 2023-01-03 - 2023-03-31
# 2024Q3 n=499→ 25 long=+26.01%  comb=+26.01% SPY≈+2.49% sector≈+3.16% alpha=+23.52% sector_alpha=+22.85% IC(Batch)=+0.094
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] ensemble member 0: fit on 347 rows from range 2023-04-04 - 2023-06-30
#   [retrain] ensemble member 1: fit on 349 rows from range 2023-04-04 - 2023-06-30
#   [retrain] ensemble member 2: fit on 340 rows from range 2023-04-04 - 2023-06-30
# 2024Q4 n=528→ 27 long=-5.39%  comb=-5.39% SPY≈-4.27% sector≈-11.04% alpha=-1.12% sector_alpha=+5.65% IC(Batch)=+0.112
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] ensemble member 0: fit on 316 rows from range 2023-07-06 - 2023-10-03
#   [retrain] ensemble member 1: fit on 320 rows from range 2023-07-06 - 2023-10-03
#   [retrain] ensemble member 2: fit on 311 rows from range 2023-07-06 - 2023-10-03
# 2025Q1 n=524→ 27 long=+16.35%  comb=+16.35% SPY≈+10.78% sector≈+22.84% alpha=+5.57% sector_alpha=-6.50% IC(Batch)=+0.136
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] ensemble member 0: fit on 318 rows from range 2023-10-03 - 2023-12-26
#   [retrain] ensemble member 1: fit on 320 rows from range 2023-10-03 - 2023-12-26
#   [retrain] ensemble member 2: fit on 302 rows from range 2023-10-03 - 2023-12-26
# 2025Q2 n=543→ 28 long=+20.32%  comb=+20.32% SPY≈+8.12% sector≈+11.45% alpha=+12.20% sector_alpha=+8.87% IC(Batch)=+0.032
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] ensemble member 0: fit on 340 rows from range 2024-01-09 - 2024-03-28
#   [retrain] ensemble member 1: fit on 348 rows from range 2024-01-09 - 2024-03-28
#   [retrain] ensemble member 2: fit on 325 rows from range 2024-01-09 - 2024-03-28
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=544→ 28 long=-6.53%  comb=-6.53% SPY≈+2.67% sector≈+2.31% alpha=-9.20% sector_alpha=-8.84% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] ensemble member 0: fit on 308 rows from range 2024-04-04 - 2024-06-27
#   [retrain] ensemble member 1: fit on 318 rows from range 2024-04-04 - 2024-06-27
#   [retrain] ensemble member 2: fit on 296 rows from range 2024-04-04 - 2024-06-27
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=539→ 27 long=-4.79%  comb=-4.79% SPY≈-4.37% sector≈-7.57% alpha=-0.42% sector_alpha=+2.78% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary ────────────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.1287  (std=0.0950)
#
#   Long leg
#     Mean qtrly return   : +6.17%
#     Annualised Sharpe   : 0.856
#     Win rate            : 66.7%
#     Max drawdown        : -11.01%
#
#   Combined L/S
#     Mean qtrly return   : +6.17%
#     Annualised Sharpe   : 0.856
#     Total return        : +91.95%
#     Max drawdown        : -11.01%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : +1.76%
#     Positive-alpha quarters : 5 / 12 (41.7%)
#
#   Sector benchmark (XLK)
#     Mean qtrly return   : +5.46%
#     Total return        : +79.70%
#
#   Mean sector-level alpha : +0.71%
#     Positive sector-alpha quarters : 6 / 12 (50.0%)
#
# Saved → backtest_results_v2/backtest_technology_fixed_quarterly.csv
# Saved → backtest_results_v2/backtest_technology_fixed_trades.csv
# Plot   → backtest_results_v2/backtest_technology_fixed_plot_returns.png
# Plot   → backtest_results_v2/backtest_technology_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_XGB

EXPERIMENT    = "industrials"       # matches results/final_<NAME>_reg.ubj
SECTORS       =  [EXPERIMENT]        # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0                # 0 = long-only
REBALANCE     = "fixed"               # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_v2")

df = load_dataset(SECTORS)
START, END = infer_test_window(df)
print(f"Test window: {START}  →  {END}")

results = backtest_XGB.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
)
# Out:
# Dataset: 21,971 rows | 493 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded ensemble [industrials]  (3 models | train IC=0.0929) ICIR=1.1501
# Dataset: 21,971 rows | 493 tickers
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLI
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] matured start (2021-07-02) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-10-02
# 2023Q1 n=424→ 22 long=+21.86%  comb=+21.86% SPY≈+8.68% sector≈+6.49% alpha=+13.18% sector_alpha=+15.36% IC(Batch)=+0.266
#   [retrain] matured start (2021-09-30) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-12-31
# 2023Q2 n=434→ 22 long=+9.56%  comb=+9.56% SPY≈-3.26% sector≈-6.08% alpha=+12.82% sector_alpha=+15.63% IC(Batch)=+0.229
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] ensemble member 0: fit on 338 rows from range 2022-01-05 - 2022-04-01
#   [retrain] ensemble member 1: fit on 331 rows from range 2022-01-05 - 2022-04-01
#   [retrain] ensemble member 2: fit on 328 rows from range 2022-01-05 - 2022-04-01
# 2023Q3 n=431→ 22 long=+9.52%  comb=+9.52% SPY≈+11.06% sector≈+13.02% alpha=-1.54% sector_alpha=-3.50% IC(Batch)=+0.112
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] ensemble member 0: fit on 344 rows from range 2022-04-05 - 2022-07-01
#   [retrain] ensemble member 1: fit on 345 rows from range 2022-04-05 - 2022-07-01
#   [retrain] ensemble member 2: fit on 343 rows from range 2022-04-05 - 2022-07-01
# 2023Q4 n=435→ 22 long=+9.29%  comb=+9.29% SPY≈+10.82% sector≈+11.11% alpha=-1.53% sector_alpha=-1.82% IC(Batch)=+0.132
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] ensemble member 0: fit on 338 rows from range 2022-07-08 - 2022-09-30
#   [retrain] ensemble member 1: fit on 345 rows from range 2022-07-07 - 2022-09-30
#   [retrain] ensemble member 2: fit on 344 rows from range 2022-07-08 - 2022-09-30
# 2024Q1 n=441→ 23 long=-3.16%  comb=-3.16% SPY≈+4.78% sector≈-3.21% alpha=-7.94% sector_alpha=+0.05% IC(Batch)=+0.031
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] ensemble member 0: fit on 349 rows from range 2022-10-03 - 2022-12-29
#   [retrain] ensemble member 1: fit on 355 rows from range 2022-10-06 - 2022-12-29
#   [retrain] ensemble member 2: fit on 344 rows from range 2022-10-03 - 2022-12-29
# 2024Q2 n=454→ 23 long=+6.14%  comb=+6.14% SPY≈+5.53% sector≈+12.71% alpha=+0.60% sector_alpha=-6.57% IC(Batch)=-0.001
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] ensemble member 0: fit on 351 rows from range 2023-01-05 - 2023-03-30
#   [retrain] ensemble member 1: fit on 361 rows from range 2023-01-05 - 2023-03-30
#   [retrain] ensemble member 2: fit on 345 rows from range 2023-01-05 - 2023-03-30
# 2024Q3 n=463→ 24 long=-1.88%  comb=-1.88% SPY≈+2.49% sector≈-2.23% alpha=-4.37% sector_alpha=+0.35% IC(Batch)=+0.041
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] ensemble member 0: fit on 352 rows from range 2023-04-04 - 2023-06-29
#   [retrain] ensemble member 1: fit on 369 rows from range 2023-04-04 - 2023-06-29
#   [retrain] ensemble member 2: fit on 352 rows from range 2023-04-04 - 2023-06-29
# 2024Q4 n=463→ 24 long=-9.99%  comb=-9.99% SPY≈-4.27% sector≈-0.22% alpha=-5.72% sector_alpha=-9.77% IC(Batch)=-0.028
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] ensemble member 0: fit on 340 rows from range 2023-07-05 - 2023-09-28
#   [retrain] ensemble member 1: fit on 352 rows from range 2023-07-05 - 2023-09-28
#   [retrain] ensemble member 2: fit on 336 rows from range 2023-07-05 - 2023-09-28
# 2025Q1 n=468→ 24 long=+20.23%  comb=+20.23% SPY≈+10.78% sector≈+12.89% alpha=+9.45% sector_alpha=+7.34% IC(Batch)=+0.111
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] ensemble member 0: fit on 340 rows from range 2023-10-04 - 2023-12-22
#   [retrain] ensemble member 1: fit on 351 rows from range 2023-10-04 - 2023-12-22
#   [retrain] ensemble member 2: fit on 340 rows from range 2023-10-04 - 2023-12-22
# 2025Q2 n=472→ 24 long=+7.98%  comb=+7.98% SPY≈+8.12% sector≈+4.98% alpha=-0.14% sector_alpha=+3.00% IC(Batch)=-0.102
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] ensemble member 0: fit on 350 rows from range 2024-01-03 - 2024-03-28
#   [retrain] ensemble member 1: fit on 367 rows from range 2024-01-03 - 2024-03-28
#   [retrain] ensemble member 2: fit on 348 rows from range 2024-01-03 - 2024-03-28
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=469→ 24 long=+5.95%  comb=+5.95% SPY≈+2.67% sector≈+0.92% alpha=+3.29% sector_alpha=+5.03% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] ensemble member 0: fit on 347 rows from range 2024-04-03 - 2024-07-02
#   [retrain] ensemble member 1: fit on 368 rows from range 2024-04-03 - 2024-07-02
#   [retrain] ensemble member 2: fit on 354 rows from range 2024-04-03 - 2024-07-02
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=473→ 24 long=+13.80%  comb=+13.80% SPY≈-4.37% sector≈+4.55% alpha=+18.17% sector_alpha=+9.24% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary ────────────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.0791  (std=0.1139)
#
#   Long leg
#     Mean qtrly return   : +7.44%
#     Annualised Sharpe   : 1.362
#     Win rate            : 75.0%
#     Max drawdown        : -11.68%
#
#   Combined L/S
#     Mean qtrly return   : +7.44%
#     Annualised Sharpe   : 1.362
#     Total return        : +127.05%
#     Max drawdown        : -11.68%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : +3.02%
#     Positive-alpha quarters : 6 / 12 (50.0%)
#
#   Sector benchmark (XLI)
#     Mean qtrly return   : +4.58%
#     Total return        : +67.16%
#
#   Mean sector-level alpha : +2.86%
#     Positive sector-alpha quarters : 8 / 12 (66.7%)
#
# Saved → backtest_results_v2/backtest_industrials_fixed_quarterly.csv
# Saved → backtest_results_v2/backtest_industrials_fixed_trades.csv
# Plot   → backtest_results_v2/backtest_industrials_fixed_plot_returns.png
# Plot   → backtest_results_v2/backtest_industrials_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_XGB

EXPERIMENT    = "healthcare"       # matches results/final_<NAME>_reg.ubj
SECTORS       =  [EXPERIMENT]        # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0                # 0 = long-only
REBALANCE     = "fixed"               # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_v2")

df = load_dataset(SECTORS)
START, END = infer_test_window(df)
print(f"Test window: {START}  →  {END}")

results = backtest_XGB.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
)
# Out:
# Dataset: 19,278 rows | 670 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded ensemble [healthcare]  (3 models | train IC=0.2624) ICIR=3.2054
# Dataset: 19,278 rows | 670 tickers
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLV
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] matured start (2021-07-02) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-10-02
# 2023Q1 n=446→ 23 long=+13.39%  comb=+13.39% SPY≈+8.68% sector≈+2.95% alpha=+4.71% sector_alpha=+10.44% IC(Batch)=+0.331
#   [retrain] matured start (2021-09-30) < original train set end (2021-12-30), only using dates after train end
#   [retrain] No matured rows in window 2021-12-30 -> 2021-12-31
# 2023Q2 n=440→ 22 long=-0.82%  comb=-0.82% SPY≈-3.26% sector≈-2.74% alpha=+2.45% sector_alpha=+1.93% IC(Batch)=+0.332
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] ensemble member 0: fit on 222 rows from range 2022-01-07 - 2022-03-16
#   [retrain] ensemble member 1: fit on 237 rows from range 2022-01-07 - 2022-03-16
#   [retrain] ensemble member 2: fit on 247 rows from range 2022-01-07 - 2022-03-31
# 2023Q3 n=450→ 23 long=+8.29%  comb=+8.29% SPY≈+11.06% sector≈+8.43% alpha=-2.77% sector_alpha=-0.14% IC(Batch)=+0.189
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] ensemble member 0: fit on 259 rows from range 2022-04-07 - 2022-06-23
#   [retrain] ensemble member 1: fit on 275 rows from range 2022-04-07 - 2022-06-23
#   [retrain] ensemble member 2: fit on 268 rows from range 2022-04-07 - 2022-06-23
# 2023Q4 n=459→ 23 long=+38.66%  comb=+38.66% SPY≈+10.82% sector≈+5.92% alpha=+27.84% sector_alpha=+32.74% IC(Batch)=+0.117
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] ensemble member 0: fit on 262 rows from range 2022-07-20 - 2022-09-08
#   [retrain] ensemble member 1: fit on 286 rows from range 2022-07-20 - 2022-09-13
#   [retrain] ensemble member 2: fit on 269 rows from range 2022-07-11 - 2022-09-13
# 2024Q1 n=502→ 26 long=-12.61%  comb=-12.61% SPY≈+4.78% sector≈-0.66% alpha=-17.39% sector_alpha=-11.95% IC(Batch)=+0.151
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] ensemble member 0: fit on 269 rows from range 2022-10-11 - 2022-12-21
#   [retrain] ensemble member 1: fit on 285 rows from range 2022-10-07 - 2022-12-21
#   [retrain] ensemble member 2: fit on 274 rows from range 2022-10-11 - 2022-12-21
# 2024Q2 n=495→ 25 long=+5.13%  comb=+5.13% SPY≈+5.53% sector≈+6.67% alpha=-0.41% sector_alpha=-1.54% IC(Batch)=+0.209
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] ensemble member 0: fit on 295 rows from range 2023-01-06 - 2023-03-31
#   [retrain] ensemble member 1: fit on 291 rows from range 2023-01-06 - 2023-03-31
#   [retrain] ensemble member 2: fit on 299 rows from range 2023-01-06 - 2023-03-31
# 2024Q3 n=523→ 27 long=+6.79%  comb=+6.79% SPY≈+2.49% sector≈-10.28% alpha=+4.30% sector_alpha=+17.07% IC(Batch)=+0.140
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] ensemble member 0: fit on 287 rows from range 2023-04-04 - 2023-06-22
#   [retrain] ensemble member 1: fit on 302 rows from range 2023-04-04 - 2023-06-22
#   [retrain] ensemble member 2: fit on 291 rows from range 2023-04-04 - 2023-06-22
# 2024Q4 n=545→ 28 long=-10.09%  comb=-10.09% SPY≈-4.27% sector≈+6.55% alpha=-5.82% sector_alpha=-16.64% IC(Batch)=+0.082
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] ensemble member 0: fit on 266 rows from range 2023-07-07 - 2023-09-13
#   [retrain] ensemble member 1: fit on 272 rows from range 2023-07-07 - 2023-09-13
#   [retrain] ensemble member 2: fit on 269 rows from range 2023-07-07 - 2023-09-07
# 2025Q1 n=569→ 29 long=+13.89%  comb=+13.89% SPY≈+10.78% sector≈-7.24% alpha=+3.11% sector_alpha=+21.13% IC(Batch)=+0.132
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] ensemble member 0: fit on 256 rows from range 2023-10-04 - 2023-12-20
#   [retrain] ensemble member 1: fit on 259 rows from range 2023-10-04 - 2023-12-20
#   [retrain] ensemble member 2: fit on 254 rows from range 2023-10-04 - 2023-12-20
# 2025Q2 n=558→ 28 long=+11.58%  comb=+11.58% SPY≈+8.12% sector≈+3.72% alpha=+3.46% sector_alpha=+7.86% IC(Batch)=+0.252
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] ensemble member 0: fit on 261 rows from range 2024-01-08 - 2024-03-22
#   [retrain] ensemble member 1: fit on 268 rows from range 2024-01-08 - 2024-03-22
#   [retrain] ensemble member 2: fit on 276 rows from range 2024-01-08 - 2024-03-22
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=558→ 28 long=+2.35%  comb=+2.35% SPY≈+2.67% sector≈+11.70% alpha=-0.31% sector_alpha=-9.35% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] ensemble member 0: fit on 246 rows from range 2024-04-09 - 2024-06-20
#   [retrain] ensemble member 1: fit on 271 rows from range 2024-04-09 - 2024-06-20
#   [retrain] ensemble member 2: fit on 254 rows from range 2024-04-09 - 2024-06-20
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=552→ 28 long=-6.91%  comb=-6.91% SPY≈-4.37% sector≈-4.90% alpha=-2.54% sector_alpha=-2.01% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary ────────────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.1935  (std=0.0872)
#
#   Long leg
#     Mean qtrly return   : +5.81%
#     Annualised Sharpe   : 0.683
#     Win rate            : 66.7%
#     Max drawdown        : -12.61%
#
#   Combined L/S
#     Mean qtrly return   : +5.81%
#     Annualised Sharpe   : 0.683
#     Total return        : +80.38%
#     Max drawdown        : -12.61%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : +1.39%
#     Positive-alpha quarters : 6 / 12 (50.0%)
#
#   Sector benchmark (XLV)
#     Mean qtrly return   : +1.68%
#     Total return        : +19.05%
#
#   Mean sector-level alpha : +4.13%
#     Positive sector-alpha quarters : 6 / 12 (50.0%)
#
# Saved → backtest_results_v2/backtest_healthcare_fixed_quarterly.csv
# Saved → backtest_results_v2/backtest_healthcare_fixed_trades.csv
# Plot   → backtest_results_v2/backtest_healthcare_fixed_plot_returns.png
# Plot   → backtest_results_v2/backtest_healthcare_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_MLP

EXPERIMENT    = "full_dataset"       # matches results_mlp/final_<NAME>_mlp_*.joblib
SECTORS       = None#[EXPERIMENT]         # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0.0                    # 0 = long-only
REBALANCE     = "fixed"                # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_mlp")

df = load_dataset(SECTORS)
START, END = infer_test_window(df, test_months=24)
print(f"Test window: {START}  →  {END}")
# Out:
# Dataset: 146,809 rows | 3,773 tickers
# Test window: 2023-03-31  →  2026-03-15

# %%
results = backtest_MLP.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
)
# Out:
# Loaded MLP ensemble [full_dataset] (3 models, methods=['permutation', 'mutual_info', 'lasso'])
# Loaded MLP ensemble [full_dataset]  (3 models | test IC=0.0662 ICIR=1.1782)
# Dataset: 146,809 rows | 3,773 tickers
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Derived train cutoff (retrain guard): 2021-12-30
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] Skipping 2023Q1: matured window 2021-07-02 -> 2021-10-02 overlaps training date
# 2023Q1 n=3032→152 long=+5.12%  comb=+5.12% SPY≈+8.68%  alpha=-3.56% IC(Batch)=+0.118
#   [retrain] Skipping 2023Q2: matured window 2021-09-30 -> 2021-12-31 overlaps training date
# 2023Q2 n=3079→154 long=-5.29%  comb=-5.29% SPY≈-3.26%  alpha=-2.03% IC(Batch)=+0.135
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] MLP ensemble member 0: fit on 2183 rows
#   [retrain] MLP ensemble member 1: fit on 2224 rows
#   [retrain] MLP ensemble member 2: fit on 2312 rows
# 2023Q3 n=3088→155 long=+12.58%  comb=+12.58% SPY≈+11.06%  alpha=+1.52% IC(Batch)=+0.178
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] MLP ensemble member 0: fit on 2243 rows
#   [retrain] MLP ensemble member 1: fit on 2427 rows
#   [retrain] MLP ensemble member 2: fit on 2334 rows
# 2023Q4 n=3136→157 long=+9.48%  comb=+9.48% SPY≈+10.82%  alpha=-1.33% IC(Batch)=+0.072
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] MLP ensemble member 0: fit on 2276 rows
#   [retrain] MLP ensemble member 1: fit on 2429 rows
#   [retrain] MLP ensemble member 2: fit on 2365 rows
# 2024Q1 n=3147→158 long=-2.97%  comb=-2.97% SPY≈+4.78%  alpha=-7.75% IC(Batch)=+0.019
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] MLP ensemble member 0: fit on 2318 rows
#   [retrain] MLP ensemble member 1: fit on 2514 rows
#   [retrain] MLP ensemble member 2: fit on 2413 rows
# 2024Q2 n=3311→166 long=+8.66%  comb=+8.66% SPY≈+5.53%  alpha=+3.12% IC(Batch)=+0.069
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] MLP ensemble member 0: fit on 2329 rows
#   [retrain] MLP ensemble member 1: fit on 2554 rows
#   [retrain] MLP ensemble member 2: fit on 2478 rows
# 2024Q3 n=3371→169 long=-3.09%  comb=-3.09% SPY≈+2.49%  alpha=-5.58% IC(Batch)=+0.080
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] MLP ensemble member 0: fit on 2323 rows
#   [retrain] MLP ensemble member 1: fit on 2599 rows
#   [retrain] MLP ensemble member 2: fit on 2558 rows
# 2024Q4 n=3468→174 long=-2.45%  comb=-2.45% SPY≈-4.27%  alpha=+1.81% IC(Batch)=+0.068
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] MLP ensemble member 0: fit on 2271 rows
#   [retrain] MLP ensemble member 1: fit on 2480 rows
#   [retrain] MLP ensemble member 2: fit on 2409 rows
# 2025Q1 n=3474→174 long=+8.14%  comb=+8.14% SPY≈+10.78%  alpha=-2.63% IC(Batch)=+0.127
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] MLP ensemble member 0: fit on 2233 rows
#   [retrain] MLP ensemble member 1: fit on 2490 rows
#   [retrain] MLP ensemble member 2: fit on 2377 rows
# 2025Q2 n=3547→178 long=+5.66%  comb=+5.66% SPY≈+8.12%  alpha=-2.46% IC(Batch)=+0.149
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] MLP ensemble member 0: fit on 2252 rows
#   [retrain] MLP ensemble member 1: fit on 2586 rows
#   [retrain] MLP ensemble member 2: fit on 2438 rows
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=3530→177 long=+2.54%  comb=+2.54% SPY≈+2.67%  alpha=-0.13% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] MLP ensemble member 0: fit on 2221 rows
#   [retrain] MLP ensemble member 1: fit on 2576 rows
#   [retrain] MLP ensemble member 2: fit on 2384 rows
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=3510→176 long=+1.96%  comb=+1.96% SPY≈-4.37%  alpha=+6.33% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary (MLP) ──────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.1014  (std=0.0478)
#
#   Long leg
#     Mean qtrly return   : +3.36%
#     Annualised Sharpe   : 0.759
#     Win rate            : 66.7%
#     Max drawdown        : -5.47%
#
#   Combined L/S
#     Mean qtrly return   : +3.36%
#     Annualised Sharpe   : 0.759
#     Total return        : +46.11%
#     Max drawdown        : -5.47%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : -1.06%
#     Positive-alpha quarters : 4 / 12 (33.3%)
#
# Saved → backtest_results_mlp/backtest_mlp_full_dataset_fixed_quarterly.csv
# Saved → backtest_results_mlp/backtest_mlp_full_dataset_fixed_trades.csv
# Plot   → backtest_results_mlp/backtest_mlp_full_dataset_fixed_plot_returns.png
# Plot   → backtest_results_mlp/backtest_mlp_full_dataset_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_MLP

EXPERIMENT    = "financial_services"       # matches results_mlp/final_<NAME>_mlp_*.joblib
SECTORS       = [EXPERIMENT]         # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0.0                    # 0 = long-only
REBALANCE     = "fixed"                # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_mlp")

df = load_dataset(SECTORS)
START, END = infer_test_window(df, test_months=24)
print(f"Test window: {START}  →  {END}")

results = backtest_MLP.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
)
# Out:
# Dataset: 25,931 rows | 602 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded MLP ensemble [financial_services] (3 models, methods=['permutation', 'mutual_info', 'lasso'])
# Loaded MLP ensemble [financial_services]  (3 models | test IC=0.0407 ICIR=0.6769)
# Dataset: 25,931 rows | 602 tickers
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLF
# Derived train cutoff (retrain guard): 2021-12-30
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] Skipping 2023Q1: matured window 2021-07-02 -> 2021-10-02 overlaps training date
# 2023Q1 n=533→ 27 long=-1.01%  comb=-1.01% SPY≈+8.68% sector≈+5.32% alpha=-9.69% IC(Batch)=-0.109
#   [retrain] Skipping 2023Q2: matured window 2021-09-30 -> 2021-12-31 overlaps training date
# 2023Q2 n=534→ 27 long=-3.46%  comb=-3.46% SPY≈-3.26% sector≈-2.00% alpha=-0.20% IC(Batch)=-0.027
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] MLP ensemble member 0: fit on 379 rows
#   [retrain] MLP ensemble member 1: fit on 435 rows
#   [retrain] MLP ensemble member 2: fit on 386 rows
# 2023Q3 n=541→ 28 long=+15.64%  comb=+15.64% SPY≈+11.06% sector≈+15.38% alpha=+4.58% IC(Batch)=+0.100
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] MLP ensemble member 0: fit on 386 rows
#   [retrain] MLP ensemble member 1: fit on 438 rows
#   [retrain] MLP ensemble member 2: fit on 394 rows
# 2023Q4 n=544→ 28 long=+9.25%  comb=+9.25% SPY≈+10.82% sector≈+11.36% alpha=-1.57% IC(Batch)=-0.037
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] MLP ensemble member 0: fit on 390 rows
#   [retrain] MLP ensemble member 1: fit on 442 rows
#   [retrain] MLP ensemble member 2: fit on 391 rows
# 2024Q1 n=539→ 27 long=+2.60%  comb=+2.60% SPY≈+4.78% sector≈-1.26% alpha=-2.17% IC(Batch)=-0.085
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] MLP ensemble member 0: fit on 379 rows
#   [retrain] MLP ensemble member 1: fit on 448 rows
#   [retrain] MLP ensemble member 2: fit on 397 rows
# 2024Q2 n=555→ 28 long=+12.07%  comb=+12.07% SPY≈+5.53% sector≈+10.40% alpha=+6.54% IC(Batch)=-0.012
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] MLP ensemble member 0: fit on 389 rows
#   [retrain] MLP ensemble member 1: fit on 448 rows
#   [retrain] MLP ensemble member 2: fit on 399 rows
# 2024Q3 n=560→ 28 long=+5.11%  comb=+5.11% SPY≈+2.49% sector≈+7.10% alpha=+2.62% IC(Batch)=+0.061
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] MLP ensemble member 0: fit on 399 rows
#   [retrain] MLP ensemble member 1: fit on 454 rows
#   [retrain] MLP ensemble member 2: fit on 405 rows
# 2024Q4 n=570→ 29 long=+3.73%  comb=+3.73% SPY≈-4.27% sector≈+3.44% alpha=+8.00% IC(Batch)=+0.126
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] MLP ensemble member 0: fit on 403 rows
#   [retrain] MLP ensemble member 1: fit on 456 rows
#   [retrain] MLP ensemble member 2: fit on 405 rows
# 2025Q1 n=569→ 29 long=+5.46%  comb=+5.46% SPY≈+10.78% sector≈+5.50% alpha=-5.32% IC(Batch)=-0.021
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] MLP ensemble member 0: fit on 405 rows
#   [retrain] MLP ensemble member 1: fit on 464 rows
#   [retrain] MLP ensemble member 2: fit on 402 rows
# 2025Q2 n=576→ 29 long=+14.47%  comb=+14.47% SPY≈+8.12% sector≈+3.20% alpha=+6.35% IC(Batch)=+0.026
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] MLP ensemble member 0: fit on 389 rows
#   [retrain] MLP ensemble member 1: fit on 455 rows
#   [retrain] MLP ensemble member 2: fit on 397 rows
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=577→ 29 long=-1.50%  comb=-1.50% SPY≈+2.67% sector≈+2.03% alpha=-4.17% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] MLP ensemble member 0: fit on 397 rows
#   [retrain] MLP ensemble member 1: fit on 468 rows
#   [retrain] MLP ensemble member 2: fit on 410 rows
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=575→ 29 long=-8.17%  comb=-8.17% SPY≈-4.37% sector≈-9.40% alpha=-3.80% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary (MLP) ──────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.0021  (std=0.0761)
#
#   Long leg
#     Mean qtrly return   : +4.52%
#     Annualised Sharpe   : 0.920
#     Win rate            : 66.7%
#     Max drawdown        : -9.55%
#
#   Combined L/S
#     Mean qtrly return   : +4.52%
#     Annualised Sharpe   : 0.920
#     Total return        : +65.26%
#     Max drawdown        : -9.55%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : +0.10%
#     Positive-alpha quarters : 5 / 12 (41.7%)
#
#   Sector benchmark (XLF)
#     Mean qtrly return   : +4.26%
#     Total return        : +61.18%
#
#   Mean sector-level alpha : +0.26%
#     Positive sector-alpha quarters : 6 / 12 (50.0%)
#
# Saved → backtest_results_mlp/backtest_mlp_financial_services_fixed_quarterly.csv
# Saved → backtest_results_mlp/backtest_mlp_financial_services_fixed_trades.csv
# Plot   → backtest_results_mlp/backtest_mlp_financial_services_fixed_plot_returns.png
# Plot   → backtest_results_mlp/backtest_mlp_financial_services_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_MLP

EXPERIMENT    = "technology"       # matches results_mlp/final_<NAME>_mlp_*.joblib
SECTORS       = [EXPERIMENT]         # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0.0                    # 0 = long-only
REBALANCE     = "fixed"                # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_mlp")

df = load_dataset(SECTORS)
START, END = infer_test_window(df, test_months=24)
print(f"Test window: {START}  →  {END}")

results = backtest_MLP.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
)
# Out:
# Dataset: 20,389 rows | 561 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded MLP ensemble [technology] (3 models, methods=['permutation', 'mutual_info', 'lasso'])
# Loaded MLP ensemble [technology]  (3 models | test IC=0.0784 ICIR=0.6731)
# Dataset: 20,389 rows | 561 tickers
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLK
# Derived train cutoff (retrain guard): 2021-12-30
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] Skipping 2023Q1: matured window 2021-07-02 -> 2021-10-02 overlaps training date
# 2023Q1 n=414→ 21 long=+10.21%  comb=+10.21% SPY≈+8.68% sector≈+15.37% alpha=+1.53% IC(Batch)=+0.144
#   [retrain] Skipping 2023Q2: matured window 2021-09-30 -> 2021-12-31 overlaps training date
# 2023Q2 n=425→ 22 long=-9.05%  comb=-9.05% SPY≈-3.26% sector≈-4.50% alpha=-5.79% IC(Batch)=+0.192
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] MLP ensemble member 0: fit on 323 rows
#   [retrain] MLP ensemble member 1: fit on 305 rows
#   [retrain] MLP ensemble member 2: fit on 311 rows
# 2023Q3 n=428→ 22 long=+9.54%  comb=+9.54% SPY≈+11.06% sector≈+13.38% alpha=-1.52% IC(Batch)=+0.191
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] MLP ensemble member 0: fit on 341 rows
#   [retrain] MLP ensemble member 1: fit on 325 rows
#   [retrain] MLP ensemble member 2: fit on 313 rows
# 2023Q4 n=445→ 23 long=+6.47%  comb=+6.47% SPY≈+10.82% sector≈+11.61% alpha=-4.35% IC(Batch)=+0.165
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] MLP ensemble member 0: fit on 341 rows
#   [retrain] MLP ensemble member 1: fit on 333 rows
#   [retrain] MLP ensemble member 2: fit on 312 rows
# 2024Q1 n=440→ 22 long=+4.19%  comb=+4.19% SPY≈+4.78% sector≈+9.33% alpha=-0.58% IC(Batch)=+0.127
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] MLP ensemble member 0: fit on 354 rows
#   [retrain] MLP ensemble member 1: fit on 365 rows
#   [retrain] MLP ensemble member 2: fit on 323 rows
# 2024Q2 n=479→ 24 long=+5.68%  comb=+5.68% SPY≈+5.53% sector≈-0.78% alpha=+0.14% IC(Batch)=+0.135
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] MLP ensemble member 0: fit on 363 rows
#   [retrain] MLP ensemble member 1: fit on 361 rows
#   [retrain] MLP ensemble member 2: fit on 336 rows
# 2024Q3 n=499→ 25 long=+5.34%  comb=+5.34% SPY≈+2.49% sector≈+3.16% alpha=+2.85% IC(Batch)=+0.064
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] MLP ensemble member 0: fit on 366 rows
#   [retrain] MLP ensemble member 1: fit on 376 rows
#   [retrain] MLP ensemble member 2: fit on 366 rows
# 2024Q4 n=528→ 27 long=-9.46%  comb=-9.46% SPY≈-4.27% sector≈-11.04% alpha=-5.19% IC(Batch)=+0.013
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] MLP ensemble member 0: fit on 319 rows
#   [retrain] MLP ensemble member 1: fit on 329 rows
#   [retrain] MLP ensemble member 2: fit on 317 rows
# 2025Q1 n=524→ 27 long=+15.41%  comb=+15.41% SPY≈+10.78% sector≈+22.84% alpha=+4.63% IC(Batch)=+0.066
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] MLP ensemble member 0: fit on 308 rows
#   [retrain] MLP ensemble member 1: fit on 333 rows
#   [retrain] MLP ensemble member 2: fit on 313 rows
# 2025Q2 n=543→ 28 long=+9.66%  comb=+9.66% SPY≈+8.12% sector≈+11.45% alpha=+1.54% IC(Batch)=-0.114
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] MLP ensemble member 0: fit on 340 rows
#   [retrain] MLP ensemble member 1: fit on 332 rows
#   [retrain] MLP ensemble member 2: fit on 352 rows
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=544→ 28 long=-0.27%  comb=-0.27% SPY≈+2.67% sector≈+2.31% alpha=-2.94% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] MLP ensemble member 0: fit on 302 rows
#   [retrain] MLP ensemble member 1: fit on 323 rows
#   [retrain] MLP ensemble member 2: fit on 321 rows
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=539→ 27 long=-6.81%  comb=-6.81% SPY≈-4.37% sector≈-7.57% alpha=-2.43% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary (MLP) ──────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.0983  (std=0.0947)
#
#   Long leg
#     Mean qtrly return   : +3.41%
#     Annualised Sharpe   : 0.558
#     Win rate            : 66.7%
#     Max drawdown        : -9.46%
#
#   Combined L/S
#     Mean qtrly return   : +3.41%
#     Annualised Sharpe   : 0.558
#     Total return        : +44.39%
#     Max drawdown        : -9.46%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : -1.01%
#     Positive-alpha quarters : 5 / 12 (41.7%)
#
#   Sector benchmark (XLK)
#     Mean qtrly return   : +5.46%
#     Total return        : +79.70%
#
#   Mean sector-level alpha : -2.06%
#     Positive sector-alpha quarters : 4 / 12 (33.3%)
#
# Saved → backtest_results_mlp/backtest_mlp_technology_fixed_quarterly.csv
# Saved → backtest_results_mlp/backtest_mlp_technology_fixed_trades.csv
# Plot   → backtest_results_mlp/backtest_mlp_technology_fixed_plot_returns.png
# Plot   → backtest_results_mlp/backtest_mlp_technology_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_MLP

EXPERIMENT    = "industrials"       # matches results_mlp/final_<NAME>_mlp_*.joblib
SECTORS       = [EXPERIMENT]         # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0.0                    # 0 = long-only
REBALANCE     = "fixed"                # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_mlp")

df = load_dataset(SECTORS)
START, END = infer_test_window(df, test_months=24)
print(f"Test window: {START}  →  {END}")

results = backtest_MLP.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
)
# Out:
# Dataset: 21,971 rows | 493 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded MLP ensemble [industrials] (3 models, methods=['permutation', 'mutual_info', 'lasso'])
# Loaded MLP ensemble [industrials]  (3 models | test IC=0.0918 ICIR=1.7083)
# Dataset: 21,971 rows | 493 tickers
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLI
# Derived train cutoff (retrain guard): 2021-12-30
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] Skipping 2023Q1: matured window 2021-07-02 -> 2021-10-02 overlaps training date
# 2023Q1 n=424→ 22 long=+12.61%  comb=+12.61% SPY≈+8.68% sector≈+6.49% alpha=+3.93% IC(Batch)=+0.218
#   [retrain] Skipping 2023Q2: matured window 2021-09-30 -> 2021-12-31 overlaps training date
# 2023Q2 n=434→ 22 long=-3.30%  comb=-3.30% SPY≈-3.26% sector≈-6.08% alpha=-0.03% IC(Batch)=+0.153
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] MLP ensemble member 0: fit on 338 rows
#   [retrain] MLP ensemble member 1: fit on 340 rows
#   [retrain] MLP ensemble member 2: fit on 355 rows
# 2023Q3 n=431→ 22 long=+13.80%  comb=+13.80% SPY≈+11.06% sector≈+13.02% alpha=+2.74% IC(Batch)=+0.183
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] MLP ensemble member 0: fit on 356 rows
#   [retrain] MLP ensemble member 1: fit on 363 rows
#   [retrain] MLP ensemble member 2: fit on 359 rows
# 2023Q4 n=435→ 22 long=+14.64%  comb=+14.64% SPY≈+10.82% sector≈+11.11% alpha=+3.82% IC(Batch)=+0.154
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] MLP ensemble member 0: fit on 354 rows
#   [retrain] MLP ensemble member 1: fit on 368 rows
#   [retrain] MLP ensemble member 2: fit on 366 rows
# 2024Q1 n=441→ 23 long=-3.29%  comb=-3.29% SPY≈+4.78% sector≈-3.21% alpha=-8.07% IC(Batch)=+0.073
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] MLP ensemble member 0: fit on 363 rows
#   [retrain] MLP ensemble member 1: fit on 378 rows
#   [retrain] MLP ensemble member 2: fit on 357 rows
# 2024Q2 n=454→ 23 long=+14.91%  comb=+14.91% SPY≈+5.53% sector≈+12.71% alpha=+9.37% IC(Batch)=+0.095
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] MLP ensemble member 0: fit on 365 rows
#   [retrain] MLP ensemble member 1: fit on 384 rows
#   [retrain] MLP ensemble member 2: fit on 360 rows
# 2024Q3 n=463→ 24 long=-1.43%  comb=-1.43% SPY≈+2.49% sector≈-2.23% alpha=-3.92% IC(Batch)=+0.050
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] MLP ensemble member 0: fit on 375 rows
#   [retrain] MLP ensemble member 1: fit on 393 rows
#   [retrain] MLP ensemble member 2: fit on 376 rows
# 2024Q4 n=463→ 24 long=-12.22%  comb=-12.22% SPY≈-4.27% sector≈-0.22% alpha=-7.95% IC(Batch)=+0.074
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] MLP ensemble member 0: fit on 366 rows
#   [retrain] MLP ensemble member 1: fit on 372 rows
#   [retrain] MLP ensemble member 2: fit on 365 rows
# 2025Q1 n=468→ 24 long=+18.22%  comb=+18.22% SPY≈+10.78% sector≈+12.89% alpha=+7.44% IC(Batch)=+0.138
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] MLP ensemble member 0: fit on 367 rows
#   [retrain] MLP ensemble member 1: fit on 374 rows
#   [retrain] MLP ensemble member 2: fit on 356 rows
# 2025Q2 n=472→ 24 long=+10.01%  comb=+10.01% SPY≈+8.12% sector≈+4.98% alpha=+1.89% IC(Batch)=+0.097
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] MLP ensemble member 0: fit on 361 rows
#   [retrain] MLP ensemble member 1: fit on 382 rows
#   [retrain] MLP ensemble member 2: fit on 373 rows
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=469→ 24 long=+3.89%  comb=+3.89% SPY≈+2.67% sector≈+0.92% alpha=+1.23% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] MLP ensemble member 0: fit on 379 rows
#   [retrain] MLP ensemble member 1: fit on 375 rows
#   [retrain] MLP ensemble member 2: fit on 367 rows
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=473→ 24 long=+0.44%  comb=+0.44% SPY≈-4.37% sector≈+4.55% alpha=+4.81% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary (MLP) ──────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.1235  (std=0.0543)
#
#   Long leg
#     Mean qtrly return   : +5.69%
#     Annualised Sharpe   : 0.945
#     Win rate            : 66.7%
#     Max drawdown        : -13.48%
#
#   Combined L/S
#     Mean qtrly return   : +5.69%
#     Annualised Sharpe   : 0.945
#     Total return        : +85.37%
#     Max drawdown        : -13.48%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : +1.27%
#     Positive-alpha quarters : 8 / 12 (66.7%)
#
#   Sector benchmark (XLI)
#     Mean qtrly return   : +4.58%
#     Total return        : +67.16%
#
#   Mean sector-level alpha : +1.11%
#     Positive sector-alpha quarters : 9 / 12 (75.0%)
#
# Saved → backtest_results_mlp/backtest_mlp_industrials_fixed_quarterly.csv
# Saved → backtest_results_mlp/backtest_mlp_industrials_fixed_trades.csv
# Plot   → backtest_results_mlp/backtest_mlp_industrials_fixed_plot_returns.png
# Plot   → backtest_results_mlp/backtest_mlp_industrials_fixed_plot_risk.png

# %%
from pathlib import Path

from backtest_util import *
import backtest_MLP

EXPERIMENT    = "healthcare"       # matches results_mlp/final_<NAME>_mlp_*.joblib
SECTORS       = [EXPERIMENT]         # None = all sectors
TOP_QUANTILE  = 0.05
BOT_QUANTILE  = 0.0                    # 0 = long-only
REBALANCE     = "fixed"                # "fixed" | "staggered"
MIN_STOCKS    = 3
OUTPUT_DIR    = Path("backtest_results_mlp")

df = load_dataset(SECTORS)
START, END = infer_test_window(df, test_months=24)
print(f"Test window: {START}  →  {END}")

results = backtest_MLP.run_backtest(
    experiment_name = EXPERIMENT,
    sectors         = SECTORS,
    top_q           = TOP_QUANTILE,
    bot_q           = BOT_QUANTILE,
    start_date      = START,
    end_date        = END,
    rebalance_mode  = REBALANCE,
    min_stocks      = MIN_STOCKS,
    output_dir      = OUTPUT_DIR,
)
# Out:
# Dataset: 19,278 rows | 670 tickers
# Test window: 2023-03-31  →  2026-03-15
# Loaded MLP ensemble [healthcare] (3 models, methods=['permutation', 'mutual_info', 'lasso'])
# Loaded MLP ensemble [healthcare]  (3 models | test IC=0.1800 ICIR=2.5756)
# Dataset: 19,278 rows | 670 tickers
#
# Backtest  2023Q1 → 2026Q1  (13 Qs)  mode=fixed  long=5%  short=0%
#
# Sector baseline ETF: XLV
# Derived train cutoff (retrain guard): 2021-12-30
# Quarters:   0%|          | 0/12 [00:00<?, ?it/s]
#   [retrain] Skipping 2023Q1: matured window 2021-07-02 -> 2021-10-02 overlaps training date
# 2023Q1 n=446→ 23 long=+12.61%  comb=+12.61% SPY≈+8.68% sector≈+2.95% alpha=+3.93% IC(Batch)=+0.243
#   [retrain] Skipping 2023Q2: matured window 2021-09-30 -> 2021-12-31 overlaps training date
# 2023Q2 n=440→ 22 long=-7.80%  comb=-7.80% SPY≈-3.26% sector≈-2.74% alpha=-4.54% IC(Batch)=+0.199
#   [retrain] q_start: 2023-07-01, matured batch start: 2022-01-01
#   [retrain] MLP ensemble member 0: fit on 255 rows
#   [retrain] MLP ensemble member 1: fit on 252 rows
#   [retrain] MLP ensemble member 2: fit on 279 rows
# 2023Q3 n=450→ 23 long=+30.48%  comb=+30.48% SPY≈+11.06% sector≈+8.43% alpha=+19.42% IC(Batch)=+0.192
#   [retrain] q_start: 2023-10-01, matured batch start: 2022-04-02
#   [retrain] MLP ensemble member 0: fit on 270 rows
#   [retrain] MLP ensemble member 1: fit on 320 rows
#   [retrain] MLP ensemble member 2: fit on 279 rows
# 2023Q4 n=459→ 23 long=+11.15%  comb=+11.15% SPY≈+10.82% sector≈+5.92% alpha=+0.34% IC(Batch)=+0.183
#   [retrain] q_start: 2024-01-01, matured batch start: 2022-07-02
#   [retrain] MLP ensemble member 0: fit on 275 rows
#   [retrain] MLP ensemble member 1: fit on 327 rows
#   [retrain] MLP ensemble member 2: fit on 285 rows
# 2024Q1 n=502→ 26 long=-7.51%  comb=-7.51% SPY≈+4.78% sector≈-0.66% alpha=-12.29% IC(Batch)=+0.264
#   [retrain] q_start: 2024-04-01, matured batch start: 2022-10-01
#   [retrain] MLP ensemble member 0: fit on 289 rows
#   [retrain] MLP ensemble member 1: fit on 335 rows
#   [retrain] MLP ensemble member 2: fit on 305 rows
# 2024Q2 n=495→ 25 long=+10.10%  comb=+10.10% SPY≈+5.53% sector≈+6.67% alpha=+4.56% IC(Batch)=+0.318
#   [retrain] q_start: 2024-07-01, matured batch start: 2023-01-02
#   [retrain] MLP ensemble member 0: fit on 293 rows
#   [retrain] MLP ensemble member 1: fit on 339 rows
#   [retrain] MLP ensemble member 2: fit on 317 rows
# 2024Q3 n=523→ 27 long=-8.49%  comb=-8.49% SPY≈+2.49% sector≈-10.28% alpha=-10.98% IC(Batch)=+0.120
#   [retrain] q_start: 2024-10-01, matured batch start: 2023-04-03
#   [retrain] MLP ensemble member 0: fit on 286 rows
#   [retrain] MLP ensemble member 1: fit on 343 rows
#   [retrain] MLP ensemble member 2: fit on 338 rows
# 2024Q4 n=545→ 28 long=+10.81%  comb=+10.81% SPY≈-4.27% sector≈+6.55% alpha=+15.08% IC(Batch)=+0.108
#   [retrain] q_start: 2025-01-01, matured batch start: 2023-07-03
#   [retrain] MLP ensemble member 0: fit on 263 rows
#   [retrain] MLP ensemble member 1: fit on 299 rows
#   [retrain] MLP ensemble member 2: fit on 296 rows
# 2025Q1 n=569→ 29 long=+17.02%  comb=+17.02% SPY≈+10.78% sector≈-7.24% alpha=+6.25% IC(Batch)=+0.089
#   [retrain] q_start: 2025-04-01, matured batch start: 2023-10-01
#   [retrain] MLP ensemble member 0: fit on 256 rows
#   [retrain] MLP ensemble member 1: fit on 288 rows
#   [retrain] MLP ensemble member 2: fit on 281 rows
# 2025Q2 n=558→ 28 long=+3.15%  comb=+3.15% SPY≈+8.12% sector≈+3.72% alpha=-4.97% IC(Batch)=+0.218
#   [retrain] q_start: 2025-07-01, matured batch start: 2024-01-01
#   [retrain] MLP ensemble member 0: fit on 300 rows
#   [retrain] MLP ensemble member 1: fit on 352 rows
#   [retrain] MLP ensemble member 2: fit on 323 rows
# Quarter: 2025Q3 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q3 n=558→ 28 long=+1.25%  comb=+1.25% SPY≈+2.67% sector≈+11.70% alpha=-1.41% IC(Batch)=+nan
#   [retrain] q_start: 2025-10-01, matured batch start: 2024-04-02
#   [retrain] MLP ensemble member 0: fit on 261 rows
#   [retrain] MLP ensemble member 1: fit on 293 rows
#   [retrain] MLP ensemble member 2: fit on 277 rows
# Quarter: 2025Q4 is after 2025Q2, can't derive Batch IC because target is unavailable (requires one year of future data)
# 2025Q4 n=552→ 28 long=-14.56%  comb=-14.56% SPY≈-4.37% sector≈-4.90% alpha=-10.19% IC(Batch)=+nan
# Risk-free rates loaded: mean=1.113%/qtr  (4.45% annualised)
#
# ─── Backtest Summary (MLP) ──────────────────────────────────────────
#   Mode                  : fixed
#   Risk-free rate (avg)  : 4.60%/yr  (^IRX T-bill)
#   Quarters with results : 12 / 13
#   Mean Batch IC        : +0.1932  (std=0.0726)
#
#   Long leg
#     Mean qtrly return   : +4.85%
#     Annualised Sharpe   : 0.572
#     Win rate            : 66.7%
#     Max drawdown        : -14.56%
#
#   Combined L/S
#     Mean qtrly return   : +4.85%
#     Annualised Sharpe   : 0.572
#     Total return        : +62.37%
#     Max drawdown        : -14.56%
#
#   SPY benchmark (per-position avg window)
#     Mean qtrly return   : +4.42%
#     Annualised Sharpe   : 1.124
#     Total return        : +65.08%
#     Max drawdown        : -4.37%
#
#   Mean position-level alpha : +0.43%
#     Positive-alpha quarters : 6 / 12 (50.0%)
#
#   Sector benchmark (XLV)
#     Mean qtrly return   : +1.68%
#     Total return        : +19.05%
#
#   Mean sector-level alpha : +3.18%
#     Positive sector-alpha quarters : 7 / 12 (58.3%)
#
# Saved → backtest_results_mlp/backtest_mlp_healthcare_fixed_quarterly.csv
# Saved → backtest_results_mlp/backtest_mlp_healthcare_fixed_trades.csv
# Plot   → backtest_results_mlp/backtest_mlp_healthcare_fixed_plot_returns.png
# Plot   → backtest_results_mlp/backtest_mlp_healthcare_fixed_plot_risk.png
